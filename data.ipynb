# %%
import feedparser as fp
import json
import newspaper
from newspaper import Article
from time import mktime
from datetime import datetime
import csv
from nltk.tokenize.toktok import ToktokTokenizer
import nltk

import spacy
import nltk
import re
import unicodedata

# %%
# Set the limit for number of articles to download
LIMIT = 50

data = {}
data['newspapers'] = {}

# load newspaper
with open('company.json') as data_file:
    companies = json.load(data_file)

articles_array = []    
    
count = 1
# Iterate through each news company
for company, value in companies.items():
    if 'rss' in value:
        d = fp.parse(value['rss'])
        print("Downloading articles from ", company)
        newsPaper = {
            "rss": value['rss'],
            #"link": value['link'],
            "articles": []
        }
        for entry in d.entries:
            # Check if publish date is provided, if no the article is skipped.
            # This is done to keep consistency in the data and to keep the script from crashing.
            if hasattr(entry, 'published'):
                if count > LIMIT:
                    break
                article = {}
                article['link'] = entry.link
                date = entry.published_parsed
                article['published'] = datetime.fromtimestamp(mktime(date)).isoformat()
                try:
                    content = Article(entry.link)
                    content.download()
                    content.parse()
                except Exception as e:
                    # If the download for some reason fails (ex. 404) the script will continue downloading
                    # the next article.
                    print(e)
                    print("continuing...")
                    continue
                article['title'] = content.title
                article['text'] = content.text
                article['authors'] = content.authors
                article['top_image'] =  content.top_image
                article['movies'] = content.movies
                newsPaper['articles'].append(article)
                articles_array.append(article)
                print(count, "articles downloaded from", company, ", url: ", entry.link)
                count = count + 1
    else:
        # This is the fallback method if a RSS-feed link is not provided.
        # It uses the python newspaper library to extract articles
        print("Building site for ", company)
        paper = newspaper.build(value['link'], memoize_articles=False)
        newsPaper = {
            "link": value['link'],
            "articles": []
        }
        noneTypeCount = 0
        for content in paper.articles:
            if count > LIMIT:
                break
            try:
                content.download()
                content.parse()
            except Exception as e:
                print(e)
                print("continuing...")
                continue
            # Again, for consistency, if there is no found publish date the article will be skipped.

            article = {}
            article['title'] = content.title
            article['authors'] = content.authors
            article['text'] = content.text
            article['top_image'] =  content.top_image
            article['movies'] = content.movies
            article['link'] = content.url
            article['published'] = content.publish_date
            newsPaper['articles'].append(article)
            articles_array.append(article)
            print(count, "articles downloaded from", company, " using newspaper, url: ", content.url)
            count = count + 1
            #noneTypeCount = 0
    count = 1
    data['newspapers'][company] = newsPaper
    
# Finally it saves the articles as a JSON-file.
try:
    f = csv.writer(open('Scraped_data_news_output.csv', 'w', encoding='utf-8'))
    f.writerow(['Title', 'Authors','Text','Image','Videos','Link','Published_Date'])
    #print(article)
    for artist_name in articles_array:
        title = artist_name['title']
        authors=artist_name['authors']
        text=artist_name['text']
        image=artist_name['top_image']
        video=artist_name['movies']
        link=artist_name['link']
        publish_date=artist_name['published']
        # Add each artist’s name and associated link to a row
        f.writerow([title, authors, text, image, video, link, publish_date])

except Exception as e: print(e)
# Out:
# Downloading articles from  HT
# 1 articles downloaded from HT , url:  https://www.hindustantimes.com/football/some-bayern-stars-wanted-kovac-gone-reveals-hoeness/story-cC8JA1QC3zWrSxuMKion1I.html
# 2 articles downloaded from HT , url:  https://www.hindustantimes.com/football/rs-8000-ticket-drives-away-pakistan-people-from-exhibition-match-featuring-luis-figo-kaka-carles-puyol/story-eUXlydThDQ2TJ6EUBmCJwN.html
# 3 articles downloaded from HT , url:  https://www.hindustantimes.com/football/cristiano-ronaldo-hasn-t-scored-a-free-kick-in-almost-2-years-lionel-messi-hits-two-in-single-game/story-QJ385RXxEFhUYQP0jlfeWM.html
# 4 articles downloaded from HT , url:  https://www.hindustantimes.com/football/bayern-brush-aside-off-field-woes-to-thrash-dortmund-in-klassiker/story-omZuJVuDLtQVql149ZuwYI.html
# 5 articles downloaded from HT , url:  https://www.hindustantimes.com/football/lionel-messi-equals-cristiano-ronaldo-s-huge-la-liga-record-with-a-hat-trick/story-sIxWnjsSHYyEkTzptyfNNI.html
# 6 articles downloaded from HT , url:  https://www.hindustantimes.com/football/premier-league-jamie-vardy-james-maddison-pull-leicester-city-further-clear-of-arsenal/story-cIZCwNWsK6bkV5btXS703N.html
# 7 articles downloaded from HT , url:  https://www.hindustantimes.com/football/tottenham-slip-to-12th-after-being-held-by-sheffield-united/story-KJaCN5uDUmmPtLjTfLprYN.html
# 8 articles downloaded from HT , url:  https://www.hindustantimes.com/football/barcelona-president-reveals-club-is-preparing-for-the-post-lionel-messi-era/story-upLPvSDobTs75ud0AXmyKL.html
# 9 articles downloaded from HT , url:  https://www.hindustantimes.com/football/atk-crush-jamshedpur-3-1-to-climb-to-top-spot/story-qVGrIWuM6367Z5dE0gq62I.html
# 10 articles downloaded from HT , url:  https://www.hindustantimes.com/football/chelsea-go-second-in-premier-league-with-sixth-win-on-the-trot/story-88na9HXSHff55cBkOkSXJI.html
# 11 articles downloaded from HT , url:  https://www.hindustantimes.com/football/manchester-city-goalkeeper-ederson-out-of-liverpool-clash-says-pep-guardiola/story-QMOIvZC0fqFLBBYYvN12VO.html
# 12 articles downloaded from HT , url:  https://www.hindustantimes.com/football/kerala-blasters-odisha-fc-settle-for-a-point-as-injuries-take-a-toll/story-4k80qHPZxowNZpQdJ2xYlN.html
# 13 articles downloaded from HT , url:  https://www.hindustantimes.com/football/ibrahimovic-set-for-ac-milan-return-says-mls-chief/story-yvpPGqJtFZokyXoNz1SswO.html
# 14 articles downloaded from HT , url:  https://www.hindustantimes.com/football/man-utd-ease-into-last-32-celtic-down-lazio-to-progress/story-EMxI5FzLjlYRe1HyzVGk8L.html
# 15 articles downloaded from HT , url:  https://www.hindustantimes.com/football/fc-goa-win-goal-fest-against-mumbai-city-fc-in-isl/story-4kurdMAqh3m1OdjOPgYmUL.html

# %%
import pandas as pd

# %%
df_articles = pd.read_csv('Scraped_data_news_output.csv')

# %%
df_articles.head()
# Out:
#                                                Title  \
# 0  Some Bayern stars wanted Kovac gone, reveals H...
# 1  Rs 8000 ticket drives away Pakistan people fro...
# 2  Cristiano Ronaldo hasn’t scored a free-kick in...
# 3  Bayern brush aside off-field woes to thrash Do...
# 4  Lionel Messi equals Cristiano Ronaldo’s huge L...
#
#                     Authors  \
# 0                        []
# 1  ['Press Trust Of India']
# 2      ['Ht Correspondent']
# 3  ['Press Trust Of India']
# 4      ['Ht Correspondent']
#
#                                                 Text  \
# 0  football\r\n\r\nUpdated: Nov 10, 2019 20:21 IS...
# 1  football\r\n\r\nUpdated: Nov 10, 2019 18:10 IS...
# 2  football\r\n\r\nUpdated: Nov 10, 2019 17:08 IS...
# 3  football\r\n\r\nUpdated: Nov 10, 2019 13:37 IS...
# 4  football\r\n\r\nUpdated: Nov 10, 2019 12:14 IS...
#
#                                                Image  \
# 0  https://www.hindustantimes.com/rf/image_size_9...
# 1  https://www.hindustantimes.com/rf/image_size_9...
# 2  https://www.hindustantimes.com/rf/image_size_9...
# 3  https://www.hindustantimes.com/rf/image_size_9...
# 4  https://www.hindustantimes.com/rf/image_size_9...
#
#                                           Videos  \
# 0                                             []
# 1                                             []
# 2                                             []
# 3                                             []
# 4  ['https://www.youtube.com/embed/bheqPBjrzAw']
#
#                                                 Link       Published_Date
# 0  https://www.hindustantimes.com/football/some-b...  2019-11-10T02:51:30
# 1  https://www.hindustantimes.com/football/rs-800...  2019-11-10T12:40:37
# 2  https://www.hindustantimes.com/football/cristi...  2019-11-10T11:38:54
# 3  https://www.hindustantimes.com/football/bayern...  2019-11-10T08:07:24
# 4  https://www.hindustantimes.com/football/lionel...  2019-11-10T06:44:13

# %%
df = df_articles.filter(["Title", "Text"])
df
# Out:
#                                                 Title  \
# 0   Some Bayern stars wanted Kovac gone, reveals H...
# 1   Rs 8000 ticket drives away Pakistan people fro...
# 2   Cristiano Ronaldo hasn’t scored a free-kick in...
# 3   Bayern brush aside off-field woes to thrash Do...
# 4   Lionel Messi equals Cristiano Ronaldo’s huge L...
# 5   Premier League: Jamie Vardy, James Maddison pu...
# 6   Tottenham slip to 12th after being held by She...
# 7   Barcelona president reveals club is preparing ...
# 8   ISL 2019: ATK crush Jamshedpur 3-1 to climb to...
# 9   Chelsea go second in Premier League with sixth...
# 10  Manchester City goalkeeper Ederson out of Live...
# 11  Kerala Blasters, Odisha FC settle for a point ...
# 12  Ibrahimovic set for AC Milan return, says MLS ...
# 13  Man Utd ease into last 32, Celtic down Lazio t...
#
#                                                  Text
# 0   football\r\n\r\nUpdated: Nov 10, 2019 20:21 IS...
# 1   football\r\n\r\nUpdated: Nov 10, 2019 18:10 IS...
# 2   football\r\n\r\nUpdated: Nov 10, 2019 17:08 IS...
# 3   football\r\n\r\nUpdated: Nov 10, 2019 13:37 IS...
# 4   football\r\n\r\nUpdated: Nov 10, 2019 12:14 IS...
# 5   football\r\n\r\nUpdated: Nov 10, 2019 09:13 IS...
# 6   football\r\n\r\nUpdated: Nov 09, 2019 23:54 IS...
# 7   football\r\n\r\nUpdated: Nov 09, 2019 23:12 IS...
# 8   football\r\n\r\nUpdated: Nov 09, 2019 22:27 IS...
# 9   football\r\n\r\nUpdated: Nov 09, 2019 20:57 IS...
# 10  football\r\n\r\nUpdated: Nov 08, 2019 23:49 IS...
# 11  football\r\n\r\nUpdated: Nov 08, 2019 23:42 IS...
# 12  football\r\n\r\nUpdated: Nov 08, 2019 10:36 IS...
# 13  football\r\n\r\nUpdated: Nov 08, 2019 10:08 IS...

# %%
for i in range(0,df.last_valid_index()+1):
    x = df.iloc[i]['Text']
    a = df.iloc[i]['Text'][43:(len(x)-41)]
    df.iloc[i]['Text'] = a

# %%
df.head()
# Out:
#                                                Title  \
# 0           Bayern star want Kovac go reveal Hoeness
# 1  rs 8000 ticket drive away Pakistan people exhi...
# 2  Cristiano Ronaldo not score free-kick almost 2...
# 3  Bayern brush aside off-field woe thrash Dortmu...
# 4  Lionel Messi equal Cristiano Ronaldo ' huge La...
#
#                                                 Text
# 0  Bayern Munich president Uli Hoeness reveal clu...
# 1  legendary footballer Luis Figo Kaka Carles Puy...
# 2  comparison Lionel Messi Cristiano Ronaldo refu...
# 3  Managerless Bayern Munich thrash Borussia Dort...
# 4  despite fact former real Madrid forward Cristi...

# %% [markdown]
# ## do the following
# cd stanford-corenlp-full-2018-02-27
#
# java -mx4g -cp "*" edu.stanford.nlp.pipeline.StanfordCoreNLPServer -annotators "tokenize,ssplit,pos,lemma,parse,sentiment" -port 9000 -timeout 30000

# %%
# Run `pip install stanfordcorenlp` to install stanfordcorenlp package

from stanfordcorenlp import StanfordCoreNLP
import json, string

# %%
# Connect to the CoreNLP server we just started
nlp = StanfordCoreNLP('http://localhost', port=9000, timeout=30000)

# %%
# Define proporties needed to get lemma
props = {'annotators': 'pos,lemma,ner',
         'pipelineLanguage': 'en',
         'outputFormat': 'json'}

# %%
def lemmatize_corenlp(conn_nlp, sentence):
    props = {
        'annotators': 'pos,lemma',
        'pipelineLanguage': 'en',
        'outputFormat': 'json'
    }
# tokenize into words
    sents = conn_nlp.word_tokenize(sentence)

    # remove punctuations from tokenised list
    sents_no_punct = [s for s in sents if s not in string.punctuation]

    # form sentence
    sentence2 = " ".join(sents_no_punct)

    # annotate to get lemma
    parsed_str = conn_nlp.annotate(sentence2, properties=props)
    parsed_dict = json.loads(parsed_str)

    # extract the lemma for each word
    lemma_list = [v for d in parsed_dict['sentences'][0]['tokens'] for k,v in d.items() if k == 'lemma']

    # form sentence and return it
    return " ".join(lemma_list)
    
    

# make the connection and call `lemmatize_corenlp`
nlp = StanfordCoreNLP('http://localhost', port=9000, timeout=30000)

# %%
for i in range(0, df.last_valid_index()+1):
    df.iloc[i]['Title'] = lemmatize_corenlp(nlp, sentence=df.iloc[i]['Title'])
    df.iloc[i]['Text'] = lemmatize_corenlp(conn_nlp=nlp, sentence=df.iloc[i]['Text'])

# %%
tokenizer = ToktokTokenizer()
stopword_list = nltk.corpus.stopwords.words('english')
stopword_list.remove('no')
stopword_list.remove('not')

# %% [markdown]
# ## Stop words removal

# %%
def remove_stopwords(text, is_lower_case=False):
  tokens=tokenizer.tokenize(text)
  tokens=[token.strip() for token in tokens]
  if is_lower_case:
     filtered_tokens = [token for token in tokens if token not in stopword_list]
  else:
     filtered_tokens = [token for token in tokens if token.lower() not in stopword_list]
      
  filtered_text=' '.join(filtered_tokens)
  return filtered_text
remove_stopwords("The, and, if are stopwords, computer is not")
# Out:
# ', , stopwords , computer not'

# %%
for i in range(0, df.last_valid_index()+1):
    df.iloc[i]['Title'] = remove_stopwords(df.iloc[i]['Title'], True)
    df.iloc[i]['Text'] = remove_stopwords(df.iloc[i]['Text'], True)

# %%
def normalize_corpus(corpus,text_lemmatization=True, special_char_removal=True, text_lower_case=True,
                     stopword_removal=True, remove_digits=True):
    
    
    normalized_corpus=[]
    for doc in corpus:
        if text_lemmatization:
            doc=lemmatize_corenlp(nlp, doc)
      
        #remove stop words
        if stopword_removal:
            
            doc=remove_stopwords(doc, is_lower_case=text_lower_case)

        normalized_corpus.append(doc)
    
    return normalized_corpus

# %% [markdown]
# ## preprocessing of original dataset df_articles
# ### preprocessing of df is after this

# %%
df_articles['full_text']=df_articles["Title"].map(str)+'.'+df_articles["Text"]
df_articles['full_text'].head()
# Out:
# 0    Some Bayern stars wanted Kovac gone, reveals H...
# 1    Rs 8000 ticket drives away Pakistan people fro...
# 2    Cristiano Ronaldo hasn’t scored a free-kick in...
# 3    Bayern brush aside off-field woes to thrash Do...
# 4    Lionel Messi equals Cristiano Ronaldo’s huge L...
# Name: full_text, dtype: object

# %%
df_articles['clean_text']=normalize_corpus(df_articles['full_text'])

# %%
norm_corpus=list(df_articles['clean_text'])
df_articles.iloc[1][['full_text', 'clean_text']].to_dict()
# Out:
# {'full_text': 'Rs 8000 ticket drives away Pakistan people from exhibition match featuring Luis Figo, Kaka, Carles Puyol.football\r\n\r\nUpdated: Nov 10, 2019 18:10 IST\r\n\r\nLegendary footballers Luis Figo, Kaka, Carles Puyol and Nicolas Anelka were disappointed to see a sparse crowd turn up for their exhibition match in Karachi, which is part of an initiative to promote the game in Pakistan.\r\n\r\nThe six-a-side exhibition game which was held at the Rahat Stadium on Saturday between Kaka XI and local side, Karachi FC, saw just a few hundred people in attendance.\r\n\r\nMany attributed it to the expensive pricing of tickets which were sold at 8000 rupees each.\r\n\r\n“It is to uplift the sport of football in Pakistan,” World Soccer Stars organiser Robert Head said in a statement.\r\n\r\nThe players have been brought to Pakistan for the second time in two years by the World Stars organizers but the present visit appears to have drawn little response or appreciation from the football fans in the country.\r\n\r\nOne reason could be the lack of international exposure for the national team players as presently a committee of FIFA is managing football affairs in the country.\r\n\r\n“We want to contribute to football (in Pakistan) in any way we can,” said Kaka at a news conference.\r\n\r\n“This is the first step towards that.”',
#  'clean_text': "rs 8000 ticket drive away Pakistan people exhibition match feature Luis Figo Kaka Carles Puyol.football Updated Nov 10 2019 18 : 10 IST Legendary footballer Luis Figo Kaka Carles Puyol Nicolas Anelka disappoint see sparse crowd turn exhibition match Karachi part initiative promote game Pakistan six-a-side exhibition game hold Rahat Stadium Saturday Kaka XI local side Karachi FC see hundred people attendance many attribute expensive pricing ticket sell 8000 rupee ` ` uplift sport football Pakistan ' ' World Soccer Stars organiser Robert Head say statement player bring Pakistan second time two year World Stars organizer present visit appear draw little response appreciation football fan country one reason could lack international exposure national team player presently committee FIFA manage football affair country ` ` want contribute football Pakistan way ' ' say Kaka news conference ` ` first step towards ' '"}

# %% [markdown]
# ## preprocessed csv

# %%
df_articles.to_csv('news.csv', index=False,encoding='utf-8')

# %%
news_df=pd.read_csv('news.csv')

# %%
news_df.head()
# Out:
#                                                Title  \
# 0  Some Bayern stars wanted Kovac gone, reveals H...
# 1  Rs 8000 ticket drives away Pakistan people fro...
# 2  Cristiano Ronaldo hasn’t scored a free-kick in...
# 3  Bayern brush aside off-field woes to thrash Do...
# 4  Lionel Messi equals Cristiano Ronaldo’s huge L...
#
#                     Authors  \
# 0                        []
# 1  ['Press Trust Of India']
# 2      ['Ht Correspondent']
# 3  ['Press Trust Of India']
# 4      ['Ht Correspondent']
#
#                                                 Text  \
# 0  football\r\n\r\nUpdated: Nov 10, 2019 20:21 IS...
# 1  football\r\n\r\nUpdated: Nov 10, 2019 18:10 IS...
# 2  football\r\n\r\nUpdated: Nov 10, 2019 17:08 IS...
# 3  football\r\n\r\nUpdated: Nov 10, 2019 13:37 IS...
# 4  football\r\n\r\nUpdated: Nov 10, 2019 12:14 IS...
#
#                                                Image  \
# 0  https://www.hindustantimes.com/rf/image_size_9...
# 1  https://www.hindustantimes.com/rf/image_size_9...
# 2  https://www.hindustantimes.com/rf/image_size_9...
# 3  https://www.hindustantimes.com/rf/image_size_9...
# 4  https://www.hindustantimes.com/rf/image_size_9...
#
#                                           Videos  \
# 0                                             []
# 1                                             []
# 2                                             []
# 3                                             []
# 4  ['https://www.youtube.com/embed/bheqPBjrzAw']
#
#                                                 Link       Published_Date  \
# 0  https://www.hindustantimes.com/football/some-b...  2019-11-10T02:51:30
# 1  https://www.hindustantimes.com/football/rs-800...  2019-11-10T12:40:37
# 2  https://www.hindustantimes.com/football/cristi...  2019-11-10T11:38:54
# 3  https://www.hindustantimes.com/football/bayern...  2019-11-10T08:07:24
# 4  https://www.hindustantimes.com/football/lionel...  2019-11-10T06:44:13
#
#                                            full_text  \
# 0  Some Bayern stars wanted Kovac gone, reveals H...
# 1  Rs 8000 ticket drives away Pakistan people fro...
# 2  Cristiano Ronaldo hasn’t scored a free-kick in...
# 3  Bayern brush aside off-field woes to thrash Do...
# 4  Lionel Messi equals Cristiano Ronaldo’s huge L...
#
#                                           clean_text
# 0  Bayern star want Kovac go reveal Hoeness.footb...
# 1  rs 8000 ticket drive away Pakistan people exhi...
# 2  Cristiano Ronaldo not score free-kick almost 2...
# 3  Bayern brush aside off-field woe thrash Dortmu...
# 4  Lionel Messi equal Cristiano Ronaldo ' huge La...

# %% [markdown]
# ## preprocessing of df i.e. of title and text only

# %%
df['full_text']=df["Title"].map(str)+'.'+df["Text"]
df['full_text'].head()
# Out:
# 0    Bayern star want Kovac go reveal Hoeness.Bayer...
# 1    rs 8000 ticket drive away Pakistan people exhi...
# 2    Cristiano Ronaldo not score free-kick almost 2...
# 3    Bayern brush aside off-field woe thrash Dortmu...
# 4    Lionel Messi equal Cristiano Ronaldo ' huge La...
# Name: full_text, dtype: object

# %%
df['clean_text']=normalize_corpus(df['full_text'])

# %%
norm_corpus=list(df['clean_text'])
df.iloc[1][['full_text', 'clean_text']].to_dict()
# Out:
# {'full_text': "rs 8000 ticket drive away Pakistan people exhibition match feature Luis Figo Kaka Carles Puyol.legendary footballer Luis Figo Kaka Carles Puyol Nicolas Anelka disappoint see sparse crowd turn exhibition match Karachi part initiative promote game Pakistan six-a-side exhibition game hold Rahat Stadium Saturday Kaka XI local side Karachi FC see hundred people attendance many attribute expensive pricing ticket sell 8000 rupee ` ` uplift sport football Pakistan ' ' World Soccer Stars organiser Robert Head say statement player bring Pakistan second time two year World Stars organizer present visit appear draw little response appreciation football fan country one reason could lack international exposure national team player presently committee FIFA manage football affair country ` ` want contribute football Pakistan way ' ' say Kaka news conference",
#  'clean_text': 'r 8000 ticket drive away Pakistan people exhibition match feature Luis Figo Kaka Carles Puyol.legendary footballer Luis Figo Kaka Carles Puyol Nicolas Anelka disappoint see sparse crowd turn exhibition match Karachi part initiative promote game Pakistan six-a-side exhibition game hold Rahat Stadium Saturday Kaka XI local side Karachi FC see hundred people attendance many attribute expensive pricing ticket sell 8000 rupee uplift sport football Pakistan World Soccer Stars organiser Robert Head say statement player bring Pakistan second time two year World Stars organizer present visit appear draw little response appreciation football fan country one reason could lack international exposure national team player presently committee FIFA manage football affair country want contribute football Pakistan way say Kaka news conference'}

# %%
df.to_csv('news2.csv', index=False,encoding='utf-8')

# %%
news_df2=pd.read_csv('news2.csv')

# %%
news_df2.head()
# Out:
#                                                Title  \
# 0           Bayern star want Kovac go reveal Hoeness
# 1  rs 8000 ticket drive away Pakistan people exhi...
# 2  Cristiano Ronaldo not score free-kick almost 2...
# 3  Bayern brush aside off-field woe thrash Dortmu...
# 4  Lionel Messi equal Cristiano Ronaldo ' huge La...
#
#                                                 Text  \
# 0  Bayern Munich president Uli Hoeness reveal clu...
# 1  legendary footballer Luis Figo Kaka Carles Puy...
# 2  comparison Lionel Messi Cristiano Ronaldo refu...
# 3  Managerless Bayern Munich thrash Borussia Dort...
# 4  despite fact former real Madrid forward Cristi...
#
#                                            full_text  \
# 0  Bayern star want Kovac go reveal Hoeness.Bayer...
# 1  rs 8000 ticket drive away Pakistan people exhi...
# 2  Cristiano Ronaldo not score free-kick almost 2...
# 3  Bayern brush aside off-field woe thrash Dortmu...
# 4  Lionel Messi equal Cristiano Ronaldo ' huge La...
#
#                                           clean_text
# 0  Bayern star want Kovac go reveal Hoeness.Bayer...
# 1  r 8000 ticket drive away Pakistan people exhib...
# 2  Cristiano Ronaldo not score free-kick almost 2...
# 3  Bayern brush aside off-field woe thrash Dortmu...
# 4  Lionel Messi equal Cristiano Ronaldo huge La L...

# %% [markdown]
# ## pos tagging and ner

# %%
def pos_corenlp(conn_nlp, sentence):
    props = {
        'annotators': 'pos,lemma',
        'pipelineLanguage': 'en',
        'outputFormat': 'json'
    }
   
    parsed_str = conn_nlp.annotate(sentence, properties=props)
    parsed_dict = json.loads(parsed_str)
    for sents in parsed_dict["sentences"]:
            for word in sents["tokens"]:
                print (word["word"] + "=>" + word["pos"])

# %%
for i in range(0, df.last_valid_index()+1):
    pos_corenlp(nlp, sentence=news_df2.iloc[i]['clean_text'])
    #pos_corenlp(conn_nlp=nlp, sentence=df.iloc[i]['Text'])
# Out:
# Bayern=>NNP
# star=>NN
# want=>VBP
# Kovac=>NNP
# go=>VB
# reveal=>VB
# Hoeness.Bayern=>NNP
# Munich=>NNP
# president=>NN
# Uli=>NNP
# Hoeness=>NNP
# reveal=>VBP
# club=>NN
# boss=>NN
# decide=>VBP
# part=>NN
# company=>NN
# head=>NN
# coach=>NN
# Niko=>NNP
# Kovac=>NNP
# star=>NN
# want=>VBP
# Kovac=>NNP
# 48=>CD
# dismiss=>VB
# Bayern=>NNP
# last=>JJ
# Sunday=>NNP
# wake=>NN
# 5-1=>CD
# thrashing=>NN
# Eintracht=>NNP
# Frankfurt=>NNP
# Interim=>NNP
# coach=>NN
# hansi=>NN
# flick=>NN
# oversee=>VBP
# 2-0=>CD
# home=>NN
# win=>VBP
# Olympiakos=>NNP
# midweek=>JJ
# Bayern=>NNP
# qualify=>VB
# last=>JJ
# 16=>CD
# Champions=>NNPS
# League=>NNP
# two=>CD
# game=>NN
# leave=>NN
# Saturday=>NNP
# 4-0=>JJ
# league=>NN
# thrashing=>NN
# dortmund=>NN
# Allianz=>NNP
# Arena=>NNP
# Kovac=>NNP
# win=>VB
# Bundesliga=>NNP
# cup=>NN
# double=>RB
# last=>JJ
# season=>NN
# sack=>NN
# 16=>CD
# month=>NN
# Hoeness=>NNP
# confirm=>VBP
# broadcaster=>NN
# zdf=>NN
# late=>JJ
# Saturday=>NNP
# croatian=>JJ
# coach=>NN
# lose=>VBP
# backing=>NN
# dress=>NN
# room=>NN
# certainly=>RB
# element=>NN
# within=>IN
# team=>NN
# want=>VBP
# coach=>NN
# go=>VB
# reveal=>VBP
# hoeness=>NN
# without=>IN
# name=>NN
# although=>IN
# forward=>JJ
# Thomas=>NNP
# Mueller=>NNP
# say=>VBP
# unhappy=>JJ
# repeatedly=>RB
# bench=>NN
# Kovac=>NNP
# club=>NN
# leader=>NN
# react=>VBP
# accordingly=>RB
# Hoeness=>NNP
# say=>VBP
# Kovac=>NNP
# admit=>VB
# right=>JJ
# decision=>NN
# part=>NN
# company=>NN
# interview=>NN
# sky=>NN
# earlier=>JJR
# Hoeness=>NNP
# say=>VBP
# remain=>VBP
# contact=>NN
# Kovac=>NNP
# far=>RB
# I=>PRP
# concern=>NN
# coach=>NN
# almost=>RB
# always=>RB
# leave=>VB
# friend=>NN
# not=>RB
# happy=>JJ
# course=>NN
# I=>PRP
# think=>VBP
# also=>RB
# relieve=>VB
# Hoeness=>NNP
# step=>VB
# decade=>NN
# Bayern=>NNP
# president=>NN
# Friday=>NNP
# club=>NN
# annual=>JJ
# general=>JJ
# meeting=>NN
# say=>VBP
# absolutely=>RB
# no=>DT
# decision=>NN
# make=>VB
# replace=>VB
# Kovac=>NNP
# Hoeness=>NNP
# club=>NN
# chairman=>NN
# Karl-Heinz=>NNP
# Rummenigge=>NNP
# hint=>VB
# Saturday=>NNP
# game=>NN
# flick=>NN
# would=>MD
# stay=>VB
# past=>JJ
# November=>NNP
# 23=>CD
# deadline=>NN
# Bayern=>NNP
# next=>JJ
# league=>NN
# game=>NN
# Hoeness=>NNP
# set=>VBD
# date=>NN
# announce=>VB
# new=>JJ
# head=>NN
# coach=>NN
# ajax=>NN
# coach=>NN
# Erik=>NNP
# ten=>CD
# Hag=>NNP
# coach=>NN
# Bayern=>NNP
# reserve=>NN
# 2013-15=>CD
# Paris=>NNP
# Saint=>NNP
# Germain=>NNP
# german=>JJ
# coach=>NN
# Thomas=>NNP
# Tuchel=>NNP
# say=>VBP
# not=>RB
# leave=>VB
# respective=>JJ
# club=>NN
# season=>NN
# former=>JJ
# arsenal=>NN
# manager=>NN
# Arsene=>NNP
# Wenger=>NNP
# also=>RB
# criticise=>VBP
# Bayern=>NNP
# lack=>NN
# discretion=>NN
# put=>VBD
# statement=>NN
# say=>VBP
# turn=>NN
# 70-year-old=>JJ
# frenchman=>NN
# insist=>VBP
# speak=>VBP
# Rummenigge=>NNP
# phone=>NN
# express=>VBP
# interest=>NN
# job=>NN
# brief=>JJ
# conversation=>NN
# pair=>NN
# agree=>VBP
# speak=>VB
# next=>JJ
# week=>NN
# I=>PRP
# think=>VBP
# misunderstand=>NN
# I=>PRP
# sorry=>JJ
# Rummenigge=>NNP
# tell=>VB
# reporter=>NN
# add=>VB
# phone=>NN
# Wenger=>NNP
# come=>VB
# day=>NN
# clear=>JJ
# thing=>NN
# two=>CD
# win=>VBP
# flick=>NN
# Bayern=>NNP
# time=>NN
# upcoming=>JJ
# international=>JJ
# window=>NN
# need=>VBP
# get=>VB
# clear=>JJ
# idea=>NN
# want=>VBP
# say=>VBP
# Hoeness=>NNP
# add=>VB
# goal=>NN
# must=>MD
# long-term=>RB
# solution=>NN
# solution=>NN
# come=>VBP
# I=>PRP
# opinion=>NN
# r=>NN
# 8000=>CD
# ticket=>NN
# drive=>NN
# away=>RB
# Pakistan=>NNP
# people=>NNS
# exhibition=>NN
# match=>NN
# feature=>NN
# Luis=>NNP
# Figo=>NNP
# Kaka=>NNP
# Carles=>NNP
# Puyol.legendary=>NNP
# footballer=>NN
# Luis=>NNP
# Figo=>NNP
# Kaka=>NNP
# Carles=>NNP
# Puyol=>NNP
# Nicolas=>NNP
# Anelka=>NNP
# disappoint=>VB
# see=>VB
# sparse=>JJ
# crowd=>NN
# turn=>NN
# exhibition=>NN
# match=>NN
# Karachi=>NNP
# part=>NN
# initiative=>NN
# promote=>VBP
# game=>NN
# Pakistan=>NNP
# six-a-side=>JJ
# exhibition=>NN
# game=>NN
# hold=>VBP
# Rahat=>NNP
# Stadium=>NNP
# Saturday=>NNP
# Kaka=>NNP
# XI=>NNP
# local=>JJ
# side=>NN
# Karachi=>NNP
# FC=>NNP
# see=>VB
# hundred=>CD
# people=>NNS
# attendance=>NN
# many=>JJ
# attribute=>NN
# expensive=>JJ
# pricing=>NN
# ticket=>NN
# sell=>VBP
# 8000=>CD
# rupee=>NN
# uplift=>NN
# sport=>NN
# football=>NN
# Pakistan=>NNP
# World=>NNP
# Soccer=>NNP
# Stars=>NNP
# organiser=>NN
# Robert=>NNP
# Head=>NNP
# say=>VBP
# statement=>NN
# player=>NN
# bring=>VB
# Pakistan=>NNP
# second=>JJ
# time=>NN
# two=>CD
# year=>NN
# World=>NNP
# Stars=>NNP
# organizer=>NN
# present=>JJ
# visit=>NN
# appear=>VBP
# draw=>NN
# little=>JJ
# response=>NN
# appreciation=>NN
# football=>NN
# fan=>NN
# country=>NN
# one=>CD
# reason=>NN
# could=>MD
# lack=>VB
# international=>JJ
# exposure=>NN
# national=>JJ
# team=>NN
# player=>NN
# presently=>RB
# committee=>NN
# FIFA=>NNP
# manage=>VB
# football=>NN
# affair=>NN
# country=>NN
# want=>VBP
# contribute=>VBP
# football=>NN
# Pakistan=>NNP
# way=>NN
# say=>VBP
# Kaka=>NNP
# news=>NN
# conference=>NN
# Cristiano=>NNP
# Ronaldo=>NNP
# not=>RB
# score=>VBP
# free-kick=>NN
# almost=>RB
# 2=>CD
# year=>NN
# Lionel=>NNP
# Messi=>NNP
# hit=>VBD
# two=>CD
# single=>JJ
# game.comparison=>NN
# Lionel=>NNP
# Messi=>NNP
# Cristiano=>NNP
# Ronaldo=>NNP
# refuse=>VBP
# die=>VB
# superstar=>NN
# continue=>VBP
# talisman=>NN
# team=>NN
# however=>RB
# last=>JJ
# night=>NN
# messus=>NN
# prove=>VBP
# one=>CD
# thing=>NN
# best=>JJS
# free-kick=>NN
# taker=>NN
# world=>NN
# right=>JJ
# Barcelona=>NNP
# poor=>JJ
# form=>NN
# recently=>RB
# messi=>NNS
# make=>VBP
# sure=>JJ
# club=>NN
# stay=>NN
# touch=>NN
# distance=>NN
# La=>NNP
# Liga=>NNP
# top=>JJ
# spot=>NN
# messi=>NN
# score=>NN
# wonderful=>JJ
# hat-trick=>NN
# Celta=>NNP
# Vigo=>NNP
# Camp=>NNP
# Nou=>NNP
# help=>VB
# side=>NN
# get=>VB
# 4-1=>CD
# win=>VB
# La=>NNP
# Liga=>NNP
# along=>IN
# way=>NN
# messus=>NN
# equal=>JJ
# Ronaldo=>NNP
# record=>NN
# hat-trick=>NN
# La=>NNP
# Liga=>NNP
# history=>NN
# 34=>CD
# messus=>NN
# score=>NN
# two=>CD
# free-kick=>NN
# game=>NN
# Barcelona=>NNP
# stop=>VB
# winless=>JJ
# streak=>NN
# stroke=>NN
# half-time=>NN
# messi=>JJ
# score=>NN
# sensational=>JJ
# free=>JJ
# kick=>NN
# 25=>CD
# yard=>NN
# curl=>VBP
# wall=>NN
# right=>JJ
# corner=>NN
# goal-post=>NN
# minute=>NN
# later=>RB
# messi=>VBD
# hit=>VBN
# another=>DT
# free-kick=>NN
# top=>JJ
# corner=>NN
# complete=>JJ
# hat-trick=>NN
# messus=>NN
# hit=>VBD
# numerous=>JJ
# free-kick=>NN
# recent=>JJ
# time=>NN
# Ronaldo=>NNP
# last=>JJ
# score=>NN
# free-kick=>NN
# 694=>CD
# day=>NN
# ago=>IN
# messi=>NNS
# contract=>NN
# expire=>VBP
# 2021=>CD
# Barcelona=>NNP
# president=>NN
# Josep=>NNP
# Bartomeu=>NNP
# reveal=>VBP
# club=>NN
# offer=>NN
# messi=>NN
# lifetime=>NN
# contract=>NN
# see=>VBP
# career=>NN
# Camp=>NNP
# Nou=>NNP
# next=>IN
# two=>CD
# three=>CD
# season=>NN
# leader=>NN
# continue=>VBP
# messi=>NN
# Bartomeu=>NNP
# say=>VBP
# interview=>NN
# Associated=>NNP
# Press=>NNP
# however=>RB
# young=>JJ
# player=>NN
# come=>VBP
# come=>VBN
# abroad=>RB
# come=>VBN
# La=>NNP
# Masia=>NNP
# content=>NN
# prepare=>VB
# post-messi=>JJ
# era=>NN
# I=>PRP
# always=>RB
# make=>VBP
# comparison=>NN
# pelé=>NN
# explain=>VBP
# Bartomeu=>NNP
# Pelé=>NNP
# man=>NN
# one=>CD
# club=>NN
# Brazil=>NNP
# ...=>:
# I=>PRP
# no=>DT
# doubt=>NN
# messi=>NN
# end=>NN
# career=>NN
# footballer=>NN
# remain=>VBP
# link=>NN
# club=>NN
# rest=>NN
# life=>NN
# bartomeu=>NN
# insist=>VBP
# Leo=>NNP
# Messi=>NNP
# contract=>NN
# end=>NN
# 2021=>CD
# go=>VBP
# surely=>RB
# party=>NN
# involve=>VB
# feel=>VB
# strong=>JJ
# ambitious=>JJ
# extend=>VBP
# contract=>NN
# indefinitely=>RB
# finish=>VBP
# Bartomeu=>NNP
# emphatically=>RB
# Barcelona=>NNP
# offer=>NN
# lifetime=>NN
# contract=>NN
# club=>NN
# legend=>NN
# Andres=>NNP
# Iniesta=>NNP
# 2017=>CD
# month=>NN
# sign=>NN
# Bayern=>NNP
# brush=>NN
# aside=>RB
# off-field=>JJ
# woe=>NN
# thrash=>VBP
# Dortmund=>NNP
# Klassiker=>NNP
# Managerless=>NNP
# Bayern=>NNP
# Munich=>NNP
# thrash=>VBP
# borussia=>NN
# dortmund=>NN
# 4-0=>JJ
# der=>NN
# Klassiker=>NNP
# Robert=>NNP
# Lewandowski=>NNP
# continue=>VBP
# phenomenal=>JJ
# score=>NN
# run=>VBP
# two=>CD
# goal=>NN
# Allianz=>NNP
# Arena=>NNP
# Lewandowski=>NNP
# first-half=>JJ
# header=>NN
# 76th-minute=>JJ
# tap-in=>NN
# mean=>VB
# score=>NN
# Bayern=>NNP
# Bundesliga=>NNP
# Champions=>NNPS
# League=>NNP
# game=>NN
# season=>NN
# tally=>NN
# 23=>CD
# goal=>NN
# Serge=>NNP
# Gnabry=>NNP
# claim=>NN
# Bayern=>NNP
# second=>JJ
# visit=>NN
# captain=>NN
# mat=>NN
# hummel=>JJ
# score=>NN
# late=>JJ
# goal=>NN
# former=>JJ
# club=>NN
# dortmund=>NN
# suffer=>VBP
# another=>DT
# heavy=>JJ
# defeat=>NN
# Munich=>NNP
# also=>RB
# lose=>VBP
# 5-0=>CD
# April=>NNP
# Bayern=>NNP
# move=>VB
# third=>JJ
# level=>NN
# point=>NN
# second-placed=>JJ
# rb=>NN
# Leipzig=>NNP
# one=>CD
# behind=>IN
# leader=>NN
# borussia=>NN
# moenchengladbach=>NN
# host=>NN
# Werder=>NNP
# Bremen=>NNP
# Sunday=>NNP
# Interim=>NNP
# coach=>NN
# Hansi=>NNP
# flick=>NN
# enjoy=>VB
# second=>JJ
# win=>VBP
# charge=>NN
# since=>IN
# Niko=>NNP
# Kovac=>NNP
# sack=>NN
# last=>JJ
# Sunday=>NNP
# however=>RB
# Bayern=>NNP
# difficulty=>NN
# find=>VB
# new=>JJ
# coach=>NN
# Arsene=>NNP
# Wenger=>NNP
# Saturday=>NNP
# contradict=>VB
# claim=>NN
# turn=>NN
# Kovac=>NNP
# successor=>NN
# slam=>NN
# club=>NN
# lack=>NN
# discretion=>NN
# Bayern=>NNP
# chairman=>NN
# Karl-Heinz=>NNP
# Rummenigge=>NNP
# speak=>VBP
# Wenger=>NNP
# last=>JJ
# week=>NN
# cancel=>VB
# pre-match=>JJ
# interview=>NN
# sky=>NN
# Ajax=>NNP
# coach=>NN
# Erik=>NNP
# ten=>CD
# Hag=>NNP
# Paris=>NNP
# Saint-Germain=>NNP
# boss=>NN
# Thomas=>NNP
# Tuchel=>NNP
# already=>RB
# make=>VB
# clear=>JJ
# not=>RB
# join=>VB
# Bayern=>NNP
# season=>NN
# despite=>IN
# off-field=>JJ
# trouble=>NN
# Bayern=>NNP
# bounce=>VB
# back=>RB
# last=>JJ
# weekend=>NN
# 5-1=>CD
# drubbing=>NN
# Eintracht=>NNP
# Frankfurt=>NNP
# Lewandowski=>NNP
# score=>NN
# superb=>JJ
# header=>NN
# Benjamin=>NNP
# Pavard=>NNP
# cross=>VB
# 17=>CD
# minute=>JJ
# dortmund=>NN
# winger=>NN
# Jadon=>NNP
# Sancho=>NNP
# hook=>NN
# 36=>CD
# minute=>NN
# fail=>VBP
# make=>VB
# impact=>NN
# proceedings=>NNS
# gnabry=>JJ
# goal=>NN
# rule=>NN
# offside=>NN
# Bayern=>NNP
# go=>VB
# 1-0=>CD
# break=>NN
# Germany=>NNP
# winger=>NN
# strike=>NN
# two=>CD
# minute=>JJ
# second=>JJ
# half=>NN
# Lewandowski=>NNP
# stumble=>VB
# goal=>NN
# mercy=>NN
# gnabry=>NN
# fire=>NN
# home=>NN
# hour=>NN
# go=>VB
# side=>JJ
# 2-0=>JJ
# dortmund=>NN
# coach=>NN
# Lucien=>NNP
# Favre=>NNP
# bring=>VB
# forwards=>RB
# Marco=>NNP
# Reus=>NNP
# Paco=>NNP
# Alcacer=>NNP
# recover=>VB
# foot=>NN
# calf=>NN
# injury=>NN
# respectively=>RB
# alcacer=>JJ
# head=>NN
# hand=>NN
# fail=>VBP
# connect=>VB
# Achraf=>NNP
# Hakimi=>NNP
# cross=>VB
# 20=>CD
# minute=>JJ
# leave=>NN
# Dortmund=>NNP
# best=>JJS
# chance=>NN
# go=>VB
# beg=>VBP
# Bayern=>NNP
# third=>JJ
# come=>VBN
# lewandowski=>NNS
# finish=>VBP
# another=>DT
# counter-attack=>NN
# host=>NN
# hummel=>NN
# goal=>NN
# Leipzig=>NNP
# go=>VB
# second=>RB
# earlier=>JJR
# Timo=>NNP
# Werner=>NNP
# net=>JJ
# twice=>RB
# Leipzig=>NNP
# go=>VB
# second=>JJ
# 4-2=>CD
# win=>VBP
# Hertha=>NNP
# Berlin=>NNP
# capital=>NN
# Berlin=>NNP
# Wall=>NNP
# fall=>VB
# November=>NNP
# 9=>CD
# 1989=>CD
# mark=>NN
# 30th=>JJ
# anniversary=>NN
# replica=>NN
# wall=>NN
# divide=>NN
# Germany=>NNP
# capital=>NN
# 1961=>CD
# separated=>JJ
# Hertha=>NNP
# Leipzig=>NNP
# knock=>VB
# prior=>RB
# kick-off=>JJ
# Midfielder=>NNP
# Maximilian=>NNP
# Mittelstaedt=>NNP
# give=>VB
# Hertha=>NNP
# first-half=>JJ
# lead=>NN
# last=>JJ
# six=>CD
# minute=>NN
# Werner=>NNP
# convert=>VB
# penalty=>NN
# hat-trick=>NN
# last=>JJ
# weekend=>NN
# 8-0=>CD
# thrashing=>NN
# Mainz=>NNP
# Marcel=>NNP
# Sabitzer=>NNP
# add=>VB
# Leipzig=>NNP
# second=>JJ
# stroke=>NN
# half-time=>NN
# three=>CD
# goal=>NN
# come=>VBN
# final=>JJ
# five=>CD
# minute=>NN
# Kevin=>NNP
# Kampl=>NNP
# net=>JJ
# Leipzig=>NNP
# third=>JJ
# superb=>JJ
# left-footed=>JJ
# strike=>NN
# Werner=>NNP
# grab=>VB
# second=>JJ
# 11th=>JJ
# league=>NN
# goal=>NN
# many=>JJ
# game=>NN
# Hertha=>NNP
# striker=>NN
# Davie=>NNP
# Selke=>NNP
# score=>NN
# former=>JJ
# club=>NN
# striker=>NN
# Rouwen=>NNP
# Hennings=>NNP
# complete=>JJ
# hat-trick=>NN
# five=>CD
# minute=>NN
# time=>NN
# Fortuna=>NNP
# Duesseldorf=>NNP
# hold=>VBP
# Schalke=>NNP
# 3-3=>CD
# draw=>NN
# Royal=>NNP
# Blues=>NNP
# squander=>VB
# lead=>JJ
# three=>CD
# time=>NN
# goal=>NN
# Daniel=>NNP
# Caligiuri=>NNP
# Ozan=>NNP
# Kabak=>NNP
# Suat=>NNP
# Serdar=>NNP
# Gelsenkirchen=>NNP
# cancel=>VB
# Hennings=>NNP
# Union=>NNP
# Berlin=>NNP
# 11th=>JJ
# third=>JJ
# straight=>JJ
# win=>VBP
# Sebastian=>NNP
# Anderson=>NNP
# score=>NN
# twice=>RB
# 3-2=>CD
# victory=>NN
# Mainz=>NNP
# Augsburg=>NNP
# climb=>VB
# bottom=>JJ
# three=>CD
# 1-0=>CD
# win=>VBP
# bottom=>NN
# club=>NN
# paderborn=>NN
# Lionel=>NNP
# Messi=>NNP
# equal=>JJ
# Cristiano=>NNP
# Ronaldo=>NNP
# huge=>JJ
# La=>NNP
# Liga=>NNP
# record=>NN
# hat-trick=>NN
# despite=>IN
# fact=>NN
# former=>JJ
# real=>JJ
# Madrid=>NNP
# forward=>RB
# Cristiano=>NNP
# Ronaldo=>NNP
# serie=>NN
# club=>NN
# juventus=>NN
# since=>IN
# July=>NNP
# 2018=>CD
# rivalry=>NN
# Barcelona=>NNP
# star=>NN
# forward=>RB
# Lionel=>NNP
# Messi=>NNP
# continue=>VBP
# Saturday=>NNP
# Messi=>NNP
# register=>NN
# hat-trick=>NN
# Celta=>NNP
# Vigo=>NNP
# Camp=>NNP
# Nou=>NNP
# help=>VB
# side=>NN
# get=>VB
# 4-1=>CD
# win=>VB
# La=>NNP
# Liga=>NNP
# match=>NN
# messus=>NN
# equalise=>VB
# Ronaldo=>NNP
# record=>NN
# player=>NN
# hat-trick=>NN
# La=>NNP
# Liga=>NNP
# history=>NN
# 34=>CD
# argentine=>NN
# forward=>RB
# convert=>VBP
# kick=>NN
# spot=>NN
# 22nd=>JJ
# minute=>NN
# get=>VB
# goal=>NN
# later=>JJ
# messus=>NNS
# take=>VBP
# sensational=>JJ
# free=>JJ
# kick=>NN
# 25=>CD
# yard=>NN
# curl=>VBP
# wall=>NN
# right=>JJ
# corner=>NN
# goal-post=>NN
# stroke=>NN
# half=>NN
# time=>NN
# two=>CD
# minute=>JJ
# second=>JJ
# half=>NN
# Barca=>NNP
# star=>NN
# convert=>VB
# another=>DT
# free-kick=>NN
# similar=>JJ
# fashion=>NN
# complete=>JJ
# hat-trick=>NN
# Ronaldo=>NNP
# no=>RB
# longer=>RB
# real=>JJ
# Madrid=>NNP
# highly=>RB
# likely=>JJ
# messus=>NN
# would=>MD
# go=>VB
# surpass=>VB
# portuguese=>JJ
# international=>JJ
# stand=>NN
# sole=>JJ
# top=>JJ
# spot=>NN
# record=>NN
# book=>NN
# also=>RB
# messi=>VBP
# 427th=>JJ
# goal=>NN
# spanish=>NNP
# league=>NN
# big=>JJ
# advantage=>NN
# best=>JJS
# player=>NN
# world=>NN
# side=>NN
# also=>RB
# best=>JJS
# take=>VB
# free=>JJ
# kick=>NN
# Barcelona=>NNP
# midfielder=>NN
# Sergio=>NNP
# Busquets=>NNP
# praise=>NN
# messi=>NN
# match=>NN
# little=>RB
# little=>JJ
# improve=>VB
# free=>JJ
# kick=>NN
# use=>NN
# find=>VB
# hard=>JJ
# around=>IN
# give=>VB
# real=>JJ
# boost=>NN
# add=>VB
# win=>VB
# defend=>VB
# spanish=>NNP
# Champions=>NNPS
# reach=>VB
# back=>RB
# take=>VB
# top=>JJ
# spot=>NN
# table=>NN
# tie=>NN
# 25=>CD
# point=>NN
# real=>JJ
# Madrid=>NNP
# better=>JJR
# goal=>NN
# difference=>NN
# meanwhile=>RB
# real=>JJ
# Madrid=>NNP
# pick=>NN
# big=>JJ
# win=>VBP
# Saturday=>NNP
# defeat=>NN
# Eibar=>NNP
# away=>RB
# game=>NN
# brace=>VB
# Karim=>NNP
# Benzema=>NNP
# goal=>NN
# defender=>NN
# Sergi=>NNP
# Ramos=>NNP
# goal=>NN
# Federico=>NNP
# Valverde=>NNP
# Premier=>NNP
# League=>NNP
# Jamie=>NNP
# Vardy=>NNP
# James=>NNP
# Maddison=>NNP
# pull=>VB
# Leicester=>NNP
# City=>NNP
# clear=>JJ
# arsenal.leicester=>NN
# open=>JJ
# nine-point=>JJ
# lead=>NN
# arsenal=>NN
# battle=>NN
# Champions=>NNPS
# League=>NNP
# qualification=>NN
# move=>NN
# second=>JJ
# Premier=>NNP
# League=>NNP
# 2-0=>CD
# win=>VB
# Gunners=>NNP
# Saturday=>NNP
# Jamie=>NNP
# Vardy=>NNP
# James=>NNP
# Maddison=>NNP
# architect=>NN
# another=>DT
# fine=>JJ
# victory=>NN
# Foxes=>NNP
# English=>NNP
# duo=>NN
# strike=>NN
# space=>NN
# seven=>CD
# second-half=>JJ
# minute=>NN
# arsenal=>NN
# eight=>CD
# point=>NN
# adrift=>NN
# top=>JJ
# four=>CD
# fall=>NN
# even=>RB
# behind=>IN
# Manchester=>NNP
# City=>NNP
# avoid=>VB
# defeat=>VB
# away=>RP
# league=>NN
# leader=>NN
# Liverpool=>NNP
# Sunday=>NNP
# face=>NN
# mount=>VBP
# speculation=>NN
# future=>JJ
# Emery=>NNP
# surprisingly=>RB
# maintain=>VBP
# Mesut=>NNP
# Ozil=>NNP
# alongside=>IN
# front=>JJ
# two=>CD
# new=>JJ
# captain=>NN
# Pierre-Emerick=>NNP
# Aubameyang=>NNP
# Alexandre=>NNP
# Lacazette=>NNP
# bold=>JJ
# strategy=>NN
# nearly=>RB
# pay=>VBP
# lacazette=>NN
# fire=>NN
# first=>RB
# big=>JJ
# chance=>NN
# match=>NN
# inch=>NN
# wide=>JJ
# aubameyang=>NN
# burrow=>NN
# way=>NN
# area=>NN
# thereafter=>RB
# Leicester=>NNP
# better=>JJR
# chance=>NN
# break=>NN
# deadlock=>NN
# Vardy=>NNP
# fail=>VBP
# connect=>VB
# Ayoze=>NNP
# Perez=>NNP
# dangerous=>JJ
# cross=>NN
# Maddison=>NNP
# curl=>VB
# free-kick=>NN
# inch=>NN
# wide=>JJ
# Wilfred=>NNP
# Ndidi=>NNP
# next=>JJ
# miss=>VBP
# glorious=>JJ
# chance=>NN
# smash=>VBP
# crossbar=>NN
# goal=>NN
# gaping=>JJ
# Ricardo=>NNP
# Pereira=>NNP
# cutback=>NN
# four=>CD
# minute=>NN
# second=>JJ
# half=>NN
# arsenal=>NN
# first=>RB
# put=>VBD
# ball=>NN
# net=>JJ
# aubameyang=>NN
# supply=>NN
# characteristically=>RB
# clinical=>JJ
# finish=>NN
# rightly=>RB
# flag=>NN
# offside=>NN
# Vardy=>NNP
# excellent=>JJ
# record=>NN
# Arsenal=>NNP
# chance=>NN
# come=>VB
# Premier=>NNP
# League=>NNP
# top=>JJ
# scorer=>NN
# ruthless=>JJ
# low=>JJ
# finish=>NN
# past=>IN
# Bernd=>NNP
# Leno=>NNP
# Youri=>NNP
# Tielemans=>NNPS
# pass=>VB
# former=>JJ
# England=>NNP
# striker=>NN
# turn=>NN
# provider=>NN
# lay=>VBD
# ball=>NN
# back=>RB
# path=>NN
# maddison=>NN
# drill=>VB
# low=>JJ
# shot=>NN
# outside=>IN
# box=>NN
# arsenal=>NN
# offer=>NN
# precious=>JJ
# little=>JJ
# go=>NN
# behind=>IN
# Tottenham=>NNP
# slip=>VBP
# 12th=>JJ
# hold=>NN
# Sheffield=>NNP
# United.Tottenham=>NNP
# surrender=>VB
# lead=>JJ
# third=>JJ
# straight=>JJ
# Premier=>NNP
# League=>NNP
# game=>NN
# Sheffield=>NNP
# United=>NNP
# move=>VB
# fifth=>JJ
# thoroughly=>RB
# deserve=>VBP
# 1-1=>CD
# draw=>NN
# Tottenham=>NNP
# Hotspur=>NNP
# Stadium=>NNP
# Saturday=>NNP
# Son=>NNP
# heung-min=>JJ
# strike=>NN
# hour=>NN
# mark=>NN
# threaten=>VBP
# get=>VB
# Spurs=>NNPS
# jail=>NN
# especially=>RB
# controversial=>JJ
# var=>NN
# rule=>NN
# David=>NNP
# McGoldrick=>NNP
# equaliser=>NN
# moment=>NN
# later=>RB
# George=>NNP
# Baldock=>NNP
# cross=>VB
# find=>VB
# way=>NN
# Paulo=>NNP
# Gazzaniga=>NNP
# net=>JJ
# survive=>VBP
# var=>NN
# review=>NN
# level=>NN
# 12=>CD
# minute=>JJ
# time=>NN
# tottenham=>NN
# look=>VB
# back=>RB
# groove=>NN
# sweep=>NN
# aside=>RB
# red=>JJ
# Star=>NNP
# Belgrade=>NNP
# 4-0=>JJ
# Champions=>NNPS
# League=>NNP
# midweek=>JJ
# first=>RB
# away=>RB
# win=>VB
# competition=>NN
# since=>IN
# May=>NNP
# however=>RB
# Pochettino=>NNP
# man=>NN
# fall=>VB
# back=>RB
# bad=>JJ
# habit=>NN
# characterise=>NN
# poor=>JJ
# Premier=>NNP
# League=>NNP
# campaign=>NN
# slip=>VBP
# 12th=>JJ
# back=>RB
# run=>VB
# two=>CD
# win=>VBP
# 11=>CD
# game=>NN
# Spurs=>NNPS
# defender=>NN
# Eric=>NNP
# Dier=>NNP
# book=>NN
# 75=>CD
# seconds=>NNS
# clatter=>VBP
# Baldock=>NNP
# former=>JJ
# England=>NNP
# international=>JJ
# lucky=>JJ
# not=>RB
# send=>VB
# inside=>RB
# 20=>CD
# minute=>NN
# another=>DT
# foul=>JJ
# McGoldrick=>NNP
# Dier=>NNP
# unease=>NN
# show=>NN
# throughout=>IN
# disjointed=>JJ
# display=>NN
# host=>NN
# lucky=>JJ
# escape=>NN
# two=>CD
# occasion=>NN
# John=>NNP
# Lundstrum=>NNP
# fail=>VBP
# turn=>NN
# home=>NN
# dangerous=>JJ
# low=>JJ
# cross=>NN
# box=>NN
# midfielder=>NN
# smash=>VBP
# shoot=>NN
# post=>NN
# Son=>NNP
# free=>JJ
# play=>NN
# red=>JJ
# card=>NN
# incident=>NN
# see=>VBP
# Everton=>NNP
# Andre=>NNP
# Gomes=>NNP
# suffer=>VBP
# broken=>JJ
# ankle=>NN
# last=>JJ
# weekend=>NN
# rescind=>VBP
# south=>RB
# korean=>JJ
# distance=>NN
# Tottenham=>NNP
# dangerous=>JJ
# player=>NN
# force=>NN
# Dean=>NNP
# Henderson=>NNP
# first=>RB
# serious=>JJ
# save=>IN
# early=>JJ
# second=>JJ
# half=>NN
# United=>NNP
# start=>VB
# game=>NN
# joint=>JJ
# best=>JJS
# defensive=>JJ
# record=>NN
# league=>NN
# rare=>JJ
# slip=>NN
# Enda=>NNP
# Stevens=>NNP
# present=>JJ
# Son=>NNP
# glorious=>JJ
# chance=>NN
# deflect=>VB
# shot=>NN
# squeeze=>NN
# Henderson=>NNP
# leg=>NN
# 129=>CD
# seconds=>NNS
# later=>RB
# United=>NNP
# celebrate=>VB
# equaliser=>NN
# McGoldrick=>NNP
# convert=>VB
# Stevens=>NNP
# cross=>VB
# far=>RB
# post=>JJ
# however=>RB
# painstakingly=>RB
# long=>JJ
# check=>NN
# lundstram=>NN
# toe=>NN
# rule=>NN
# offside=>NN
# blade=>NN
# get=>VBP
# slice=>NN
# fortune=>NN
# deserve=>VBP
# baldock=>NN
# miscue=>NN
# cross=>NN
# end=>NN
# bend=>NN
# far=>RB
# post=>JJ
# Spurs=>NNPS
# late=>JJ
# flurry=>NN
# attempt=>NN
# take=>VBP
# three=>CD
# point=>NN
# Henderson=>NNP
# hand=>NN
# tip=>NN
# Lucas=>NNP
# Moura=>NNP
# effort=>NN
# home=>NN
# fan=>NN
# roundly=>RB
# b=>NN
# Barcelona=>NNP
# president=>NN
# reveal=>VBP
# club=>NN
# prepare=>VB
# post-Lionel=>NNP
# Messi=>NNP
# era.certainly=>RB
# not=>RB
# good=>JJ
# time=>NN
# Barcelona=>NNP
# Blaugurana=>NNP
# struggle=>NN
# fire=>NN
# cylinder=>NN
# La=>NNP
# Liga=>NNP
# well=>RB
# Champions=>NNPS
# League=>NNP
# look=>NN
# towards=>IN
# Lionel=>NNP
# Messi=>NNP
# answer=>VB
# little=>JJ
# magician=>NN
# able=>JJ
# win=>VBP
# match=>NN
# Catalans=>NNPS
# thing=>NN
# still=>RB
# look=>VB
# bleak=>JJ
# Barcelona=>NNP
# defeat=>NN
# Levante=>NNP
# La=>NNP
# Liga=>NNP
# Slavia=>NNP
# Praha=>NNP
# earn=>VBP
# 0-0=>JJ
# draw=>NN
# Camp=>NNP
# Nou=>NNP
# concern=>NN
# report=>NN
# messus=>VBZ
# not=>RB
# talk=>VB
# term=>NN
# new=>JJ
# signing=>NN
# Antoine=>NNP
# Griezmann=>NNP
# speculation=>NN
# regard=>NN
# messi=>NNS
# future=>JJ
# Camp=>NNP
# Nou=>NNP
# also=>RB
# five-time=>JJ
# Ballon=>NNP
# winner=>NN
# contract=>NN
# expire=>VBP
# 2021=>CD
# Barcelona=>NNP
# president=>NN
# Josep=>NNP
# Bartomeu=>NNP
# reveal=>VBP
# club=>NN
# offer=>NN
# messi=>NN
# lifetime=>NN
# contract=>NN
# see=>VBP
# career=>NN
# Camp=>NNP
# Nou=>NNP
# next=>IN
# two=>CD
# three=>CD
# season=>NN
# leader=>NN
# continue=>VBP
# messi=>NN
# Bartomeu=>NNP
# tell=>VB
# Associated=>NNP
# Press=>NNP
# however=>RB
# young=>JJ
# player=>NN
# come=>VBP
# come=>VBN
# abroad=>RB
# come=>VBN
# La=>NNP
# Masia=>NNP
# content=>NN
# prepare=>VB
# post-messi=>JJ
# era=>NN
# I=>PRP
# always=>RB
# make=>VBP
# comparison=>NN
# pelé=>NN
# explain=>VBP
# Bartomeu=>NNP
# Pelé=>NNP
# man=>NN
# one=>CD
# club=>NN
# Brazil=>NNP
# ...=>:
# I=>PRP
# no=>DT
# doubt=>NN
# messi=>NN
# end=>NN
# career=>NN
# footballer=>NN
# remain=>VBP
# link=>NN
# club=>NN
# rest=>NN
# life=>NN
# bartomeu=>NN
# insist=>VBP
# Leo=>NNP
# Messi=>NNP
# contract=>NN
# end=>NN
# 2021=>CD
# go=>VBP
# surely=>RB
# party=>NN
# involve=>VB
# feel=>VB
# strong=>JJ
# ambitious=>JJ
# extend=>VBP
# contract=>NN
# indefinitely=>RB
# Bartomeu=>NNP
# conclude=>VBP
# Barcelona=>NNP
# offer=>NN
# lifetime=>NN
# contract=>NN
# club=>NN
# legend=>NN
# Andres=>NNP
# Iniesta=>NNP
# 2017=>CD
# month=>NN
# sign=>NN
# iniesta=>NN
# move=>NN
# japanese=>JJ
# side=>NN
# Vissel=>NNP
# Kobe=>NNP
# look=>VB
# highly=>RB
# likely=>JJ
# messi=>NNS
# accept=>VBP
# contract=>NN
# extension=>NN
# move=>NN
# ISL=>NNP
# 2019=>CD
# ATK=>NNP
# crush=>NN
# Jamshedpur=>NNP
# 3-1=>CD
# climb=>NN
# top=>JJ
# spot.two-time=>JJ
# former=>JJ
# champion=>NN
# atk=>NN
# continue=>VBP
# dream=>NN
# run=>NN
# beat=>VBD
# Jamshedpur=>NNP
# FC=>NNP
# 3-1=>CD
# climb=>NN
# top=>JJ
# indian=>JJ
# Super=>NNP
# League=>NNP
# ISL=>NNP
# stand=>VB
# Saturday=>NNP
# rain-hit=>JJ
# evening=>NN
# cyclone=>NN
# Bulbul=>NNP
# make=>VB
# landfall=>NN
# near=>IN
# West=>NNP
# Bengal=>NNP
# coastline=>NN
# home=>NN
# side=>NN
# dominate=>VB
# proceedings=>NNS
# take=>VB
# 2-0=>JJ
# lead=>NN
# fijian=>JJ
# star=>NN
# forward=>RB
# Roy=>NNP
# Krishna=>NNP
# convert=>VB
# spot=>NN
# 57th=>JJ
# 71st=>JJ
# minute=>NN
# Sergio=>NNP
# Castel=>NNP
# reduce=>VB
# margin=>NN
# Jamshedpur=>NNP
# FC=>NNP
# 85th=>JJ
# minute=>NN
# yet=>RB
# another=>DT
# penalty=>NN
# Anas=>NNP
# Edathodika=>NNP
# bring=>VB
# Noe=>NNP
# Acosta=>NNP
# ugly=>JJ
# challenge=>NN
# inside=>IN
# box=>NN
# Castel=>NNP
# bury=>VB
# ease=>NN
# visitor=>NN
# fail=>VBP
# equalise=>NN
# Edu=>NNP
# Garcia=>NNP
# seal=>NN
# deal=>NN
# magnificent=>JJ
# finish=>NN
# 90=>CD
# +2=>CD
# nd=>NN
# minute=>NN
# Salt=>NNP
# Lake=>NNP
# Stadium=>NNP
# David=>NNP
# Williams=>NNP
# make=>VB
# excellent=>JJ
# cross-field=>JJ
# ball=>NN
# right=>NN
# towards=>IN
# Roy=>NNP
# Krishna=>NNP
# put=>VBD
# path=>NN
# Garcia=>NNP
# first=>JJ
# touch=>NN
# Garcia=>NNP
# take=>VB
# touch=>NN
# get=>VB
# close=>JJ
# goalkeeper=>NN
# chip=>NN
# brilliantly=>RB
# net=>JJ
# end=>NN
# Jamshedpur=>NNP
# unbeaten=>JJ
# run=>NN
# first=>RB
# away=>RB
# match=>VB
# season=>NN
# Antonio=>NNP
# Lopez=>NNP
# habas-coached=>JJ
# side=>NN
# endure=>VB
# disappointing=>JJ
# start=>NN
# lose=>VBP
# Kerala=>NNP
# 2-1=>CD
# isl-6=>NN
# opener=>NN
# thus=>RB
# secure=>JJ
# hat-trick=>NN
# win=>VB
# thrash=>VB
# Hyderabad=>NNP
# FC=>NNP
# 5-0=>CD
# hard-fought=>JJ
# 1-0=>CD
# away=>RB
# win=>VB
# Chennaiyin=>NNP
# FC=>NNP
# previous=>JJ
# match=>NN
# Kolkata=>NNP
# franchise=>NN
# nine=>CD
# point=>NN
# four=>CD
# match=>NN
# occupy=>VBP
# top=>JJ
# spot=>NN
# ahead=>RB
# FC=>NNP
# Goa=>NNP
# eight=>CD
# point=>NN
# Jamshedpur=>NNP
# FC=>NNP
# push=>NN
# fourth=>JJ
# place=>NN
# seven=>CD
# point=>NN
# four=>CD
# match=>NN
# player=>NN
# team=>NN
# find=>VB
# difficult=>JJ
# keep=>VB
# balance=>NN
# rain=>NN
# incessantly=>RB
# day=>NN
# atk=>NN
# concede=>VBP
# one=>CD
# chance=>NN
# entire=>JJ
# half=>NN
# biggest=>JJS
# game=>NN
# Farukh=>NNP
# Choudhary=>NNP
# header=>NN
# come=>VB
# crossbar=>RB
# early=>JJ
# eighth=>JJ
# minute=>NN
# except=>IN
# ATK=>NNP
# front-line=>JJ
# top-notch=>JJ
# put=>JJ
# immense=>JJ
# pressure=>NN
# Subrata=>NNP
# Paul=>NNP
# charge=>NN
# every=>DT
# possible=>JJ
# opportunity=>NN
# David=>NNP
# Williams=>NNP
# also=>RB
# chance=>NN
# 19th=>JJ
# minute=>NN
# header=>NN
# go=>VBP
# wide=>JJ
# goal=>NN
# Prabir=>NNP
# Das=>NNP
# right=>NN
# Michael=>NNP
# Soosairaj=>NNP
# leave=>VB
# keep=>VB
# troubling=>JJ
# Jamshedpur=>NNP
# FC=>NNP
# along=>IN
# miss=>VBP
# target=>NN
# visitor=>NN
# receive=>VBP
# setback=>NN
# spanish=>NNP
# attack=>NN
# mid-fielder=>NN
# Piti=>NNP
# limp=>JJ
# field=>NN
# Noe=>NNP
# Acosta=>NNP
# replace=>VB
# Chelsea=>NNP
# go=>VB
# second=>JJ
# Premier=>NNP
# League=>NNP
# sixth=>JJ
# win=>VBP
# trot.chelsea=>NN
# manager=>NN
# Frank=>NNP
# Lampard=>NNP
# insist=>VBP
# side=>JJ
# target=>NN
# still=>RB
# reduce=>VB
# gap=>NN
# title=>NN
# favourite=>JJ
# liverpool=>NN
# Manchester=>NNP
# City=>NNP
# despite=>IN
# leapfrog=>VBP
# City=>NNP
# second=>JJ
# place=>NN
# sixth=>JJ
# straight=>JJ
# Premier=>NNP
# League=>NNP
# win=>VB
# Saturday=>NNP
# in-form=>JJ
# Tammy=>NNP
# Abraham=>NNP
# Christian=>NNP
# pulisic=>JJ
# strike=>NN
# second=>JJ
# half=>NN
# beat=>VBD
# Crystal=>NNP
# Palace=>NNP
# 2-0=>CD
# Stamford=>NNP
# Bridge=>NNP
# Chelsea=>NNP
# edge=>NN
# point=>NN
# clear=>JJ
# city=>NN
# within=>IN
# five=>CD
# leader=>NN
# Liverpool=>NNP
# host=>NN
# city=>NN
# highly-anticipated=>JJ
# clash=>NN
# Sunday=>NNP
# respect=>NN
# Liverpool=>NNP
# Manchester=>NNP
# City=>NNP
# gap=>NN
# try=>VB
# bridge=>JJ
# way=>NN
# go=>VB
# season=>NN
# Lampard=>NNP
# tell=>VB
# BT=>NNP
# Sport=>NNP
# possibility=>NN
# title=>NN
# challenge=>NN
# happy=>JJ
# 4-4=>CD
# draw=>NN
# ajax=>NN
# Tuesday=>NNP
# take=>VB
# tally=>NN
# goal=>NN
# Chelsea=>NNP
# prior=>RB
# 18=>CD
# game=>NN
# season=>NN
# 70=>CD
# average=>JJ
# nearly=>RB
# four=>CD
# per=>IN
# game=>NN
# however=>RB
# Blues=>NNP
# free=>JJ
# flow=>NN
# football=>NN
# meet=>VBP
# brick=>NN
# wall=>NN
# palace=>NN
# defence=>NN
# first=>JJ
# 45=>CD
# minute=>NN
# I=>PRP
# little=>JJ
# bit=>NN
# frustrated=>JJ
# I=>PRP
# feel=>VBP
# allow=>VB
# tempo=>NN
# drop=>NN
# first=>JJ
# half=>NN
# add=>VB
# Lampard=>NNP
# I=>PRP
# feel=>VBP
# increase=>NN
# tempo=>NN
# game=>NN
# win=>VBP
# pulisic=>JJ
# score=>NN
# four=>CD
# goal=>NN
# last=>JJ
# two=>CD
# Premier=>NNP
# League=>NNP
# game=>NN
# american=>NN
# begin=>VB
# deliver=>VB
# £=>$
# 58=>CD
# million=>CD
# 74=>CD
# million=>CD
# price=>NN
# tag=>NN
# fine=>JJ
# save=>IN
# Vicente=>NNP
# Guaita=>NNP
# deny=>VBP
# USA=>NNP
# captain=>NN
# another=>DT
# strike=>NN
# early=>RB
# thereafter=>RB
# Chelsea=>NNP
# largely=>RB
# restricted=>JJ
# effort=>NN
# free-kick=>NN
# edge=>NN
# box=>NN
# break=>NN
# willian=>JJ
# curl=>VBP
# inch=>NN
# wide=>JJ
# Gary=>NNP
# Cahill=>NNP
# make=>VB
# return=>NN
# Stamford=>NNP
# Bridge=>NNP
# seven=>CD
# year=>NN
# Chelsea=>NNP
# player=>NN
# come=>VB
# end=>NN
# summer=>NN
# Cahill=>NNP
# remind=>VB
# former=>JJ
# employer=>NN
# win=>VB
# eight=>CD
# trophy=>NN
# club=>NN
# brilliant=>JJ
# block=>NN
# repel=>VB
# willian=>JJ
# goalbound=>JJ
# effort=>NN
# first=>JJ
# half=>NN
# stoppage=>NN
# time=>NN
# palace=>NN
# resistence=>NN
# finally=>RB
# break=>VB
# one=>CD
# moment=>NN
# genius=>NN
# Willian=>NNP
# Chelsea=>NNP
# captain=>NN
# day=>NN
# flick=>NN
# ball=>NN
# perfectly=>RB
# Abraham=>NNP
# path=>NN
# slot=>NN
# home=>NN
# 10th=>JJ
# Premier=>NNP
# League=>NNP
# goal=>NN
# season=>NN
# join=>VB
# Leicester=>NNP
# Jamie=>NNP
# Vardy=>NNP
# top=>JJ
# scorer=>NN
# division=>NN
# Abraham=>NNP
# one=>CD
# host=>NN
# youngster=>NN
# shine=>VBP
# since=>IN
# hand=>NN
# chance=>NN
# first=>JJ
# team=>NN
# lampard=>NN
# number=>NN
# nine=>CD
# Chelsea=>NNP
# world=>NN
# class=>NN
# striker=>NN
# I=>PRP
# feel=>VBP
# ready=>JJ
# I=>PRP
# proud=>JJ
# say=>VBP
# Abraham=>NNP
# Pulisic=>NNP
# test=>NN
# Guaita=>NNP
# rise=>NN
# drive=>NN
# shortly=>RB
# spaniard=>VBD
# brilliantly=>RB
# tip=>NN
# guaita=>NN
# helpless=>JJ
# 11=>CD
# minute=>JJ
# time=>NN
# pulisic=>JJ
# finally=>RB
# get=>VB
# goal=>NN
# performance=>NN
# deserve=>VBP
# follow=>VB
# Michy=>NNP
# Batsh=>NNP
# Manchester=>NNP
# City=>NNP
# goalkeeper=>NN
# Ederson=>NNP
# Liverpool=>NNP
# clash=>NN
# say=>VBP
# pep=>NN
# Guardiola.Manchester=>NNP
# City=>NNP
# keeper=>NN
# Ederson=>NNP
# miss=>VBP
# Sunday=>NNP
# Premier=>NNP
# League=>NNP
# match=>NN
# leader=>NN
# Liverpool=>NNP
# due=>JJ
# muscle=>NN
# injury=>NN
# Claudio=>NNP
# Bravo=>NNP
# set=>VBD
# replace=>VB
# goal=>NN
# manager=>NN
# Pep=>NNP
# Guardiola=>NNP
# say=>VBP
# Friday=>NNP
# Ederson=>NNP
# lead=>VB
# Premier=>NNP
# League=>NNP
# five=>CD
# clean=>JJ
# sheet=>NN
# season=>NN
# force=>NN
# halftime=>NN
# Wednesday=>NNP
# 1-1=>CD
# Champions=>NNPS
# League=>NNP
# draw=>NN
# Atalanta=>NNP
# brazilian=>JJ
# see=>VBP
# walk=>NN
# limp=>JJ
# game=>NN
# Bravo=>NNP
# send=>VB
# late=>JJ
# game=>NN
# force=>NN
# City=>NNP
# play=>VB
# defender=>NN
# Kyle=>NNP
# Walker=>NNP
# goal=>NN
# final=>JJ
# 10=>CD
# minute=>NN
# Guardiola=>NNP
# say=>VB
# trust=>NN
# experienced=>JJ
# chilean=>JJ
# deliver=>VB
# top-of-the-table=>JJ
# clash=>NN
# Ederson=>NNP
# not=>RB
# able=>JJ
# play=>NN
# Sunday=>NNP
# another=>DT
# top=>JJ
# goalkeeper=>NN
# Claudio=>NNP
# Bravo=>NNP
# Guardiola=>NNP
# tell=>VB
# reporter=>NN
# win=>VB
# Carabao=>NNP
# Cup=>NNP
# FA=>NNP
# Cup=>NNP
# thanks=>NNS
# Claudio=>NNP
# Bravo=>NNP
# exceptional=>JJ
# goalkeeper=>NN
# ...=>:
# international=>JJ
# goalkeeper=>NN
# I=>PRP
# no=>DT
# doubt=>NN
# I=>PRP
# see=>VBP
# every=>DT
# day=>NN
# training=>NN
# not=>RB
# lose=>VB
# Claudio=>NNP
# red=>JJ
# card=>NN
# day=>NN
# lose=>VB
# ball=>NN
# respect=>NN
# guy=>NN
# incredible=>JJ
# top=>JJ
# goalkeeper=>NN
# Liverpool=>NNP
# City=>NNP
# play=>VB
# goalless=>JJ
# draw=>NN
# Anfield=>NNP
# last=>JJ
# season=>NN
# though=>IN
# question=>NN
# Guardiola=>NNP
# City=>NNP
# defensive=>JJ
# mindset=>NN
# say=>VBP
# consequence=>NN
# adapt=>VBP
# Liverpool=>NNP
# strategy=>NN
# sometimes=>RB
# want=>VBP
# adapt=>VBP
# team=>NN
# good=>JJ
# Liverpool=>NNP
# Guardiola=>NNP
# say=>VBP
# sometimes=>RB
# people=>NNS
# recognise=>VBP
# play=>NN
# champion=>NN
# Europe=>NNP
# defensive=>JJ
# not=>RB
# plan=>VB
# good=>JJ
# push=>NN
# deep=>JJ
# everything=>NN
# well=>RB
# see=>VBP
# team=>NN
# weak=>JJ
# point=>NN
# real=>JJ
# complete=>JJ
# team=>NN
# need=>NN
# kind=>NN
# rival=>JJ
# win=>VB
# Liverpool=>NNP
# see=>VB
# extend=>VB
# lead=>NN
# defend=>VBP
# champion=>NN
# nine=>CD
# point=>NN
# Guardiola=>NNP
# say=>VB
# case=>NN
# would=>MD
# become=>VB
# tougher=>JJR
# reel=>NN
# Juergen=>NNP
# Klopp=>NNP
# side=>NN
# lose=>VB
# one=>CD
# game=>NN
# last=>JJ
# season=>NN
# I=>PRP
# think=>VBP
# November=>NNP
# title=>NN
# race=>NN
# never=>RB
# end=>VB
# add=>VB
# I=>PRP
# know=>VBP
# go=>VB
# happen=>VB
# lose=>VB
# ...=>:
# I=>PRP
# think=>VBP
# lot=>NN
# game=>NN
# play=>NN
# lot=>NN
# difficult=>JJ
# course=>NN
# see=>VB
# Liverpool=>NNP
# lose=>VB
# one=>CD
# game=>NN
# last=>JJ
# season=>NN
# season=>NN
# unbeaten=>NN
# imagine=>VBP
# think=>VBP
# not=>RB
# go=>VB
# lose=>VB
# many=>JJ
# game=>NN
# Klopp=>NNP
# take=>VB
# team=>NN
# not=>RB
# real=>JJ
# contender=>NN
# win=>VB
# Premier=>NNP
# League=>NNP
# --=>:
# three=>CD
# four=>CD
# year=>NN
# Kerala=>NNP
# Blasters=>NNP
# Odisha=>NNP
# FC=>NNP
# settle=>VB
# point=>NN
# injury=>NN
# take=>VB
# toll.kerala=>JJ
# blaster=>NN
# FC=>NN
# remain=>VBP
# without=>IN
# win=>VB
# third=>JJ
# consecutive=>JJ
# match=>NN
# indian=>JJ
# Super=>NNP
# League=>NNP
# ISL=>NNP
# follow=>VB
# goalless=>JJ
# draw=>NN
# Odisha=>NNP
# FC=>NNP
# Jawaharlal=>NNP
# Nehru=>NNP
# Stadium=>NNP
# Friday=>NNP
# contest=>NN
# mar=>FW
# injury=>NN
# key=>JJ
# player=>NN
# team=>NN
# Jairo=>NNP
# Rodriguez=>NNP
# Raphael=>NNP
# Messi=>NNP
# Bouli=>NNP
# Aridane=>NNP
# Santana=>NNP
# substitute=>NN
# first=>RB
# half=>DT
# change=>NN
# affect=>VB
# pace=>NN
# game=>NN
# ultimately=>RB
# end=>VB
# without=>IN
# winner=>NN
# blaster=>NN
# odisha=>NN
# four=>CD
# point=>NN
# many=>JJ
# game=>NN
# occupy=>VBP
# fifth=>JJ
# sixth=>JJ
# position=>NN
# league=>NN
# table=>NN
# respectively=>RB
# Blasters=>NNP
# already=>RB
# hamper=>VBP
# injury=>NN
# season=>NN
# suffer=>VBP
# major=>JJ
# blow=>NN
# fourth=>JJ
# minute=>NN
# captain=>NN
# Jairo=>NNP
# Rodriguez=>NNP
# go=>VB
# injure=>RB
# replace=>VB
# Abdul=>NNP
# Hakku=>NNP
# however=>RB
# home=>NN
# side=>NN
# continue=>VBP
# press=>NN
# high=>JJ
# field=>NN
# try=>VB
# take=>VB
# game=>NN
# opponent=>NN
# Odisha=>NNP
# well=>RB
# organise=>VB
# back=>RB
# cautious=>JJ
# period=>NN
# play=>NN
# early=>JJ
# come=>VBN
# halt=>NN
# head-on=>JJ
# collision=>NN
# inside=>IN
# box=>NN
# follow=>VBP
# corner-kick=>NN
# leave=>NN
# Aridane=>NNP
# Santana=>NNP
# Messi=>NNP
# Bouli=>NNP
# require=>VB
# medical=>JJ
# attention=>NN
# follow=>VBP
# long=>JJ
# pause=>NN
# game=>NN
# resume=>VBP
# Mohammed=>NNP
# Rafi=>NNP
# Carlos=>NNP
# Delgado=>NNP
# replace=>VB
# injured=>JJ
# player=>NN
# team=>NN
# struggle=>NN
# create=>VB
# clear-cut=>JJ
# chance=>NN
# Sahal=>NNP
# Abdul=>NNP
# Samad=>NNP
# take=>VB
# matter=>NN
# hand=>NN
# embark=>VBP
# stellar=>JJ
# solo=>NN
# run=>NN
# pick=>NN
# ball=>NN
# right=>JJ
# flank=>NN
# midfielder=>NN
# outfox=>VB
# three=>CD
# defender=>NN
# Narayan=>NNP
# Das=>NNP
# bring=>VB
# inside=>RB
# box=>NN
# referee=>NN
# reject=>VBP
# vociferous=>JJ
# appeal=>NN
# penalty=>NN
# blaster=>NN
# better=>RBR
# side=>JJ
# first=>JJ
# half=>NN
# although=>IN
# fine=>JJ
# margin=>NN
# Mohammed=>NNP
# Rafi=>NNP
# drill=>VB
# cross=>NN
# box=>NN
# right=>NN
# meet=>VBP
# rahul=>NN
# kp=>NN
# whose=>WP$
# audacious=>JJ
# volley=>NN
# fail=>VBP
# test=>NN
# goalkeeper=>NN
# Francisco=>NNP
# Dorronsoro=>NNP
# team=>NN
# struggle=>NN
# raise=>VBP
# tempo=>NN
# keep=>VB
# hold=>VB
# ball=>NN
# break=>NN
# well=>RB
# odisha=>JJ
# threaten=>VBP
# Jerry=>NNP
# Mawihmingthanga=>NNP
# cross=>VB
# put=>VBN
# T.P.=>NNP
# Rehenesh=>NNP
# spot=>NN
# bother=>VB
# goalkeeper=>NN
# spill=>NN
# ball=>NN
# inside=>IN
# box=>NN
# Nandhakumar=>NNP
# Sekar=>NNP
# hit=>VBD
# rebound=>NN
# side-netting=>JJ
# couple=>NN
# chance=>NN
# either=>CC
# end=>NN
# game=>NN
# wound=>NN
# goal=>NN
# remain=>VBP
# elusive=>JJ
# four=>CD
# minute=>NN
# leave=>NN
# prasanth=>NN
# cross=>NN
# leave=>VBP
# flick=>NN
# towards=>IN
# far=>RB
# post=>JJ
# second-half=>JJ
# substitute=>NN
# Bartholomew=>NNP
# Ogbeche=>NNP
# Rahul=>NNP
# whose=>WP$
# firm=>JJ
# shot=>NN
# keep=>VB
# Dorronsoro=>NNP
# Daniel=>NNP
# Lalhlimpuia=>NNP
# end=>VB
# spurn=>VB
# chance=>NN
# ibrahimovic=>JJ
# set=>NN
# ac=>NN
# Milan=>NNP
# return=>NN
# say=>VB
# MLS=>NNP
# chief.Zlatan=>NNP
# Ibrahimovic=>NNP
# set=>VBD
# rejoin=>VB
# italian=>JJ
# side=>NN
# ac=>NN
# Milan=>NNP
# successful=>JJ
# stint=>NN
# LA=>NNP
# Galaxy=>NNP
# Major=>NNP
# League=>NNP
# Soccer=>NNP
# Commissioner=>NNP
# Don=>NNP
# Garber=>NNP
# say=>VBP
# 38-year-old=>JJ
# swedish=>JJ
# striker=>NN
# spend=>VBP
# past=>JJ
# 18=>CD
# month=>NN
# MLS=>NNP
# contract=>NN
# galaxy=>NN
# expire=>VBP
# end=>NN
# year=>NN
# link=>NN
# host=>NN
# european=>NN
# club=>NN
# Ibrahimovic=>NNP
# play=>VB
# Milan=>NNP
# 2010=>CD
# 2012=>CD
# score=>NN
# 42=>CD
# goal=>NN
# 61=>CD
# league=>NN
# appearance=>NN
# Garber=>NNP
# say=>VBP
# way=>NN
# back=>RB
# Serie=>NNP
# a.=>NNP
# Zlatan=>NNP
# interesting=>JJ
# guy=>NN
# tell=>VBP
# ESPN=>NNP
# keep=>VB
# hand=>NN
# full=>JJ
# inbox=>NN
# full=>JJ
# thrill-a-minute=>NN
# 38-year-old=>JJ
# guy=>NN
# recruit=>VB
# ac=>NNP
# Milan=>NNP
# one=>CD
# top=>JJ
# club=>NN
# world=>NN
# ibrahamovic=>JJ
# name=>NN
# MLS=>NNP
# best=>JJS
# xi=>NN
# 2018=>CD
# 2019=>CD
# net=>JJ
# 53=>CD
# goal=>NN
# competition=>NN
# season=>NN
# galaxy=>NN
# end=>NN
# suffer=>VBP
# 5-3=>JJ
# defeat=>NN
# local=>JJ
# rival=>JJ
# Los=>NNP
# Angeles=>NNP
# Football=>NNP
# Club=>NNP
# MLS=>NNP
# Cup=>NNP
# W=>NNP
# man=>NN
# Utd=>NNP
# ease=>NN
# last=>JJ
# 32=>CD
# celtic=>JJ
# Lazio=>NNP
# progress.Teenager=>NNP
# Mason=>NNP
# Greenwood=>NNP
# score=>NN
# Manchester=>NNP
# United=>NNP
# cruise=>NN
# Europa=>NNP
# League=>NNP
# last=>JJ
# 32=>CD
# 3-0=>CD
# win=>VBP
# Partizan=>NNP
# Belgrade=>NNP
# Old=>NNP
# Trafford=>NNP
# Thursday=>NNP
# Celtic=>NNP
# stun=>VBD
# Lazio=>NNP
# last-gasp=>JJ
# goal=>NN
# Rome=>NNP
# progress=>NN
# ole=>NN
# Gunnar=>NNP
# Solskjaer=>NNP
# United=>NNP
# know=>VB
# third=>JJ
# victory=>NN
# four=>CD
# Group=>NNP
# l=>NN
# game=>NN
# would=>MD
# enough=>RB
# send=>VB
# 18-year-old=>JJ
# Greenwood=>NNP
# break=>NN
# deadlock=>NN
# 22nd=>JJ
# minute=>NN
# cool=>JJ
# finish=>NN
# score=>NN
# third=>JJ
# goal=>NN
# season=>NN
# second=>JJ
# competition=>NN
# Anthony=>NNP
# Martial=>NNP
# double=>JJ
# advantage=>NN
# half-hour=>JJ
# mark=>NN
# brilliant=>JJ
# individual=>JJ
# goal=>NN
# Marcus=>NNP
# Rashford=>NNP
# lash=>VB
# home=>NN
# third=>JJ
# four=>CD
# minute=>NN
# interval=>NN
# comfortable=>JJ
# victory=>NN
# see=>VB
# United=>NNP
# bounce=>VB
# back=>RB
# 1-0=>JJ
# loss=>NN
# Bournemouth=>NNP
# last=>JJ
# weekend=>NN
# end=>NN
# three-game=>JJ
# win=>VBP
# run=>NN
# I=>PRP
# think=>VBP
# good=>JJ
# performance=>NN
# thing=>NN
# improve=>VB
# rashford=>NN
# tell=>VB
# BT=>NNP
# Sport=>NNP
# manage=>VB
# score=>NN
# three=>CD
# goal=>NN
# could=>MD
# lot=>RB
# AZ=>NNP
# Alkmaar=>NNP
# thrash=>VBP
# Astana=>NNP
# 5-0=>CD
# Kazakhstan=>NNP
# keep=>VB
# control=>NN
# race=>NN
# second=>JJ
# place=>NN
# group=>NN
# l=>NN
# behind=>IN
# United=>NNP
# eliminate=>VB
# host=>NN
# move=>NN
# four=>CD
# point=>NN
# clear=>JJ
# Partizan=>NNP
# Olivier=>NNP
# Ntcham=>NNP
# score=>NN
# dramatic=>JJ
# injury-time=>JJ
# winner=>NN
# grab=>NN
# Celtic=>NNP
# 2-1=>CD
# victory=>NN
# Lazio=>NNP
# Neil=>NNP
# Lennon=>NNP
# outfit=>NN
# remain=>VBP
# top=>JJ
# Group=>NNP
# e=>SYM
# two=>CD
# game=>NN
# remain=>VBP
# seven=>CD
# point=>NN
# clear=>JJ
# third-placed=>JJ
# Lazio=>NNP
# second=>JJ
# straight=>JJ
# win=>VBP
# Romans=>NNPS
# great=>JJ
# qualify=>VB
# two=>CD
# game=>NN
# spare=>JJ
# celtic=>JJ
# manager=>NN
# Lennon=>NNP
# tell=>VB
# uefa.com=>NNP
# early=>JJ
# say=>VBP
# far=>RB
# go=>VB
# competition=>NN
# difficult=>JJ
# opponent=>NN
# anyone=>NN
# ntcham=>NN
# strike=>NN
# Ciro=>NNP
# Immobile=>NNP
# volley=>NN
# host=>NN
# seventh-minute=>JJ
# lead=>NN
# James=>NNP
# Forrest=>NNP
# draw=>VB
# celtic=>JJ
# level=>NN
# half-time=>NN
# substitute=>NN
# ntcham=>NN
# latch=>VBP
# onto=>IN
# Odsonne=>NNP
# Edouard=>NNP
# pass=>VB
# fifth=>JJ
# minute=>NN
# add=>VB
# time=>NN
# dink=>JJ
# cool=>JJ
# finish=>NN
# Lazio=>NNP
# goalkeeper=>NN
# Thomas=>NNP
# Strakosha=>NNP
# The=>NNP
# game=>NN
# group=>NN
# see=>VBP
# CFR=>NNP
# Cluj=>NNP
# move=>VB
# within=>IN
# point=>NN
# qualification=>NN
# beat=>VBD
# Rennes=>NNP
# 1-0=>CD
# Romania=>NNP
# Celtic=>NNP
# old=>JJ
# firm=>NN
# rival=>JJ
# Rangers=>NNPS
# give=>VBP
# hope=>NN
# reach=>NN
# knockout=>JJ
# stage=>NN
# first=>JJ
# time=>NN
# since=>IN
# 2011=>CD
# massive=>JJ
# boost=>NN
# 2-0=>CD
# victory=>NN
# Porto=>NNP
# Ibrox=>NNP
# second-half=>JJ
# goal=>NN
# Alfredo=>NNP
# Morelos=>NNP
# Steven=>NNP
# Davis=>NNP
# fire=>NN
# Steven=>NNP
# Gerrard=>NNP
# man=>NN
# second=>JJ
# group=>NN
# g=>NN
# three=>CD
# point=>NN
# ahead=>RB
# feyenoord=>JJ
# dutch=>JJ
# side=>NN
# 1-1=>CD
# draw=>NN
# Young=>NNP
# Boys=>NNPS
# outstanding=>JJ
# season=>NN
# turn=>NN
# tonight=>NN
# get=>VB
# important=>JJ
# goal=>NN
# set=>VBN
# way=>NN
# Davis=>NNP
# say=>VB
# Morelos=>NNP
# colombian=>JJ
# 11th=>JJ
# Europa=>NNP
# League=>NNP
# goal=>NN
# term=>NN
# Bundesliga=>NNP
# leader=>NN
# Borussia=>NNP
# Moenchengladbach=>NNP
# grab=>VB
# first=>JJ
# win=>VB
# Europa=>NNP
# League=>NNP
# campaign=>NN
# Marcus=>NNP
# Thuram=>NNP
# 95th-minute=>JJ
# strike=>NN
# seal=>NN
# 2-1=>CD
# triumph=>NN
# Roma=>NNP
# german=>JJ
# club=>NN
# move=>NN
# second=>JJ
# group=>NN
# j=>NN
# ahead=>RB
# Roma=>NNP
# head-to-head=>JJ
# two=>CD
# point=>NN
# behind=>IN
# leader=>NN
# Istanbul=>NNP
# Basaksehir=>NNP
# see=>VB
# 10-man=>JJ
# Wolfsberger=>NNP
# 3-0=>CD
# Austria=>NNP
# wolf=>NN
# make=>VB
# three=>CD
# straight=>JJ
# Europa=>NNP
# League=>NNP
# win=>VB
# despite=>IN
# Ruben=>NNP
# Neves=>NNP
# miss=>VBP
# penalty=>NN
# Raul=>NNP
# Jimenez=>NNP
# 92nd-minute=>JJ
# goal=>NN
# grab=>NN
# 1-0=>CD
# success=>NN
# Slovan=>NNP
# Bratislava=>NNP
# Molineux=>NNP
# Nuno=>NNP
# Espirito=>NNP
# Santo=>NNP
# man=>NN
# sit=>VB
# five=>CD
# point=>NN
# clear=>JJ
# Slovan=>NNP
# second=>JJ
# Group=>NNP
# K=>NNP
# Braga=>NNP
# point=>NN
# ahead=>RB
# Premier=>NNP
# League=>NNP
# side=>NN
# top=>JJ
# beat=>NN
# Besiktas=>NNP
# 3-1=>CD
# feel=>VB
# maybe=>RB
# go=>VB
# one=>CD
# night=>NN
# say=>VBP
# wolf=>NN
# skipper=>NN
# Conor=>NNP
# Coady=>NNP
# win=>VB
# important=>JJ
# job=>NN
# well=>RB
# El=>NNP
# Haddadi=>NNP
# treble=>JJ
# former=>JJ
# Barcelona=>NNP
# winger=>NN
# Munir=>NNP
# El=>NNP
# Haddadi=>NNP
# star=>NN
# hat-trick=>NN
# sevilla=>NN
# thrash=>VBP
# Dudelange=>NNP
# 5-2=>CD
# also=>RB
# reach=>VBP
# knockout=>JJ
# round=>NN
# Record=>NNP
# five-time=>JJ
# winner=>NN
# Sevilla=>NNP
# know=>VB
# victory=>NN
# Luxembourg=>NNP
# would=>MD
# send=>VB
# Group=>NNP
# one-sided=>JJ
# win=>VBP
# also=>RB
# seal=>VB
# top=>JJ
# spot=>NN
# PSV=>NNP
# Eindhoven=>NNP
# 1978=>CD
# winner=>NN
# suffer=>VBP
# humbling=>JJ
# 4-1=>CD
# defeat=>NN
# austrian=>JJ
# team=>NN
# lask=>NN
# Linz=>NNP
# slip=>VBP
# third=>JJ
# group=>NN
# behind=>IN
# opponent=>NN
# Sporting=>NNP
# Lisbon=>NNP
# win=>VB
# 2-0=>CD
# Rosenborg=>NNP
# elsewhere=>RB
# Espanyol=>NNP
# move=>NN
# brink=>NN
# qualification=>NN
# hammer=>VBP
# nine-man=>JJ
# ludogoret=>NN
# 6-0=>CD
# gent=>JJ
# move=>NN

# %%
news_df2.head()
# Out:
#                                                Title  \
# 0           Bayern star want Kovac go reveal Hoeness
# 1  rs 8000 ticket drive away Pakistan people exhi...
# 2  Cristiano Ronaldo not score free-kick almost 2...
# 3  Bayern brush aside off-field woe thrash Dortmu...
# 4  Lionel Messi equal Cristiano Ronaldo ' huge La...
#
#                                                 Text  \
# 0  Bayern Munich president Uli Hoeness reveal clu...
# 1  legendary footballer Luis Figo Kaka Carles Puy...
# 2  comparison Lionel Messi Cristiano Ronaldo refu...
# 3  Managerless Bayern Munich thrash Borussia Dort...
# 4  despite fact former real Madrid forward Cristi...
#
#                                            full_text  \
# 0  Bayern star want Kovac go reveal Hoeness.Bayer...
# 1  rs 8000 ticket drive away Pakistan people exhi...
# 2  Cristiano Ronaldo not score free-kick almost 2...
# 3  Bayern brush aside off-field woe thrash Dortmu...
# 4  Lionel Messi equal Cristiano Ronaldo ' huge La...
#
#                                           clean_text
# 0  Bayern star want Kovac go reveal Hoeness.Bayer...
# 1  r 8000 ticket drive away Pakistan people exhib...
# 2  Cristiano Ronaldo not score free-kick almost 2...
# 3  Bayern brush aside off-field woe thrash Dortmu...
# 4  Lionel Messi equal Cristiano Ronaldo huge La L...

# %%
def ner_corenlp(conn_nlp, sentence):
    props = {
        'annotators': 'ner',
        'pipelineLanguage': 'en',
        'outputFormat': 'json'
    }
   
    parsed_str = conn_nlp.annotate(sentence, properties=props)
    parsed_dict = json.loads(parsed_str)
    for sents in parsed_dict["sentences"]:
            for word in sents["tokens"]:
                print (word["word"] + "=>" + word["ner"])

# %%
for i in range(0, df.last_valid_index()+1):
    ner_corenlp(nlp, sentence=news_df2.iloc[i]['clean_text'])
    #ner_corenlp(conn_nlp=nlp, sentence=df.iloc[i]['Text'])
# Out:
# Bayern=>ORGANIZATION
# star=>O
# want=>O
# Kovac=>PERSON
# go=>O
# reveal=>O
# Hoeness.Bayern=>ORGANIZATION
# Munich=>ORGANIZATION
# president=>TITLE
# Uli=>PERSON
# Hoeness=>PERSON
# reveal=>O
# club=>O
# boss=>TITLE
# decide=>O
# part=>O
# company=>O
# head=>TITLE
# coach=>TITLE
# Niko=>PERSON
# Kovac=>PERSON
# star=>O
# want=>O
# Kovac=>PERSON
# 48=>NUMBER
# dismiss=>O
# Bayern=>ORGANIZATION
# last=>DATE
# Sunday=>DATE
# wake=>O
# 5-1=>NUMBER
# thrashing=>O
# Eintracht=>ORGANIZATION
# Frankfurt=>ORGANIZATION
# Interim=>ORGANIZATION
# coach=>O
# hansi=>O
# flick=>O
# oversee=>O
# 2-0=>NUMBER
# home=>O
# win=>O
# Olympiakos=>ORGANIZATION
# midweek=>O
# Bayern=>ORGANIZATION
# qualify=>O
# last=>O
# 16=>NUMBER
# Champions=>MISC
# League=>MISC
# two=>NUMBER
# game=>O
# leave=>O
# Saturday=>DATE
# 4-0=>O
# league=>O
# thrashing=>O
# dortmund=>O
# Allianz=>ORGANIZATION
# Arena=>ORGANIZATION
# Kovac=>ORGANIZATION
# win=>O
# Bundesliga=>MISC
# cup=>O
# double=>O
# last=>O
# season=>O
# sack=>O
# 16=>DURATION
# month=>DURATION
# Hoeness=>PERSON
# confirm=>O
# broadcaster=>TITLE
# zdf=>O
# late=>DATE
# Saturday=>DATE
# croatian=>NATIONALITY
# coach=>TITLE
# lose=>O
# backing=>O
# dress=>O
# room=>O
# certainly=>O
# element=>O
# within=>O
# team=>O
# want=>O
# coach=>TITLE
# go=>O
# reveal=>O
# hoeness=>O
# without=>O
# name=>O
# although=>O
# forward=>O
# Thomas=>PERSON
# Mueller=>PERSON
# say=>O
# unhappy=>O
# repeatedly=>O
# bench=>O
# Kovac=>PERSON
# club=>O
# leader=>TITLE
# react=>O
# accordingly=>O
# Hoeness=>PERSON
# say=>O
# Kovac=>PERSON
# admit=>O
# right=>O
# decision=>O
# part=>O
# company=>O
# interview=>O
# sky=>O
# earlier=>O
# Hoeness=>PERSON
# say=>O
# remain=>O
# contact=>O
# Kovac=>PERSON
# far=>O
# I=>O
# concern=>O
# coach=>TITLE
# almost=>O
# always=>O
# leave=>O
# friend=>O
# not=>O
# happy=>O
# course=>O
# I=>O
# think=>O
# also=>O
# relieve=>O
# Hoeness=>PERSON
# step=>O
# decade=>DURATION
# Bayern=>ORGANIZATION
# president=>TITLE
# Friday=>DATE
# club=>O
# annual=>SET
# general=>TITLE
# meeting=>O
# say=>O
# absolutely=>O
# no=>O
# decision=>O
# make=>O
# replace=>O
# Kovac=>PERSON
# Hoeness=>PERSON
# club=>O
# chairman=>TITLE
# Karl-Heinz=>PERSON
# Rummenigge=>PERSON
# hint=>O
# Saturday=>DATE
# game=>O
# flick=>O
# would=>O
# stay=>O
# past=>DATE
# November=>DATE
# 23=>DATE
# deadline=>O
# Bayern=>ORGANIZATION
# next=>O
# league=>O
# game=>O
# Hoeness=>PERSON
# set=>O
# date=>O
# announce=>O
# new=>O
# head=>TITLE
# coach=>TITLE
# ajax=>O
# coach=>TITLE
# Erik=>PERSON
# ten=>NUMBER
# Hag=>O
# coach=>TITLE
# Bayern=>ORGANIZATION
# reserve=>O
# 2013-15=>NUMBER
# Paris=>ORGANIZATION
# Saint=>ORGANIZATION
# Germain=>ORGANIZATION
# german=>NATIONALITY
# coach=>TITLE
# Thomas=>PERSON
# Tuchel=>PERSON
# say=>O
# not=>O
# leave=>O
# respective=>O
# club=>O
# season=>O
# former=>O
# arsenal=>O
# manager=>TITLE
# Arsene=>PERSON
# Wenger=>PERSON
# also=>O
# criticise=>O
# Bayern=>ORGANIZATION
# lack=>O
# discretion=>O
# put=>O
# statement=>O
# say=>O
# turn=>O
# 70-year-old=>DURATION
# frenchman=>NATIONALITY
# insist=>O
# speak=>O
# Rummenigge=>PERSON
# phone=>O
# express=>O
# interest=>O
# job=>O
# brief=>O
# conversation=>O
# pair=>O
# agree=>O
# speak=>O
# next=>DATE
# week=>DATE
# I=>O
# think=>O
# misunderstand=>O
# I=>O
# sorry=>O
# Rummenigge=>PERSON
# tell=>O
# reporter=>TITLE
# add=>O
# phone=>O
# Wenger=>PERSON
# come=>O
# day=>DURATION
# clear=>O
# thing=>O
# two=>NUMBER
# win=>O
# flick=>O
# Bayern=>ORGANIZATION
# time=>O
# upcoming=>O
# international=>O
# window=>O
# need=>O
# get=>O
# clear=>O
# idea=>O
# want=>O
# say=>O
# Hoeness=>PERSON
# add=>O
# goal=>O
# must=>O
# long-term=>O
# solution=>O
# solution=>O
# come=>O
# I=>O
# opinion=>O
# r=>O
# 8000=>NUMBER
# ticket=>O
# drive=>O
# away=>O
# Pakistan=>COUNTRY
# people=>O
# exhibition=>O
# match=>O
# feature=>O
# Luis=>PERSON
# Figo=>PERSON
# Kaka=>PERSON
# Carles=>PERSON
# Puyol.legendary=>O
# footballer=>TITLE
# Luis=>PERSON
# Figo=>PERSON
# Kaka=>PERSON
# Carles=>PERSON
# Puyol=>PERSON
# Nicolas=>PERSON
# Anelka=>PERSON
# disappoint=>O
# see=>O
# sparse=>O
# crowd=>O
# turn=>O
# exhibition=>O
# match=>O
# Karachi=>CITY
# part=>O
# initiative=>O
# promote=>O
# game=>O
# Pakistan=>COUNTRY
# six-a-side=>O
# exhibition=>O
# game=>O
# hold=>O
# Rahat=>LOCATION
# Stadium=>LOCATION
# Saturday=>DATE
# Kaka=>O
# XI=>O
# local=>O
# side=>O
# Karachi=>ORGANIZATION
# FC=>ORGANIZATION
# see=>O
# hundred=>NUMBER
# people=>O
# attendance=>O
# many=>O
# attribute=>O
# expensive=>O
# pricing=>O
# ticket=>O
# sell=>O
# 8000=>NUMBER
# rupee=>O
# uplift=>O
# sport=>O
# football=>O
# Pakistan=>COUNTRY
# World=>ORGANIZATION
# Soccer=>ORGANIZATION
# Stars=>ORGANIZATION
# organiser=>O
# Robert=>PERSON
# Head=>PERSON
# say=>O
# statement=>O
# player=>O
# bring=>O
# Pakistan=>COUNTRY
# second=>ORDINAL
# time=>O
# two=>DURATION
# year=>DURATION
# World=>O
# Stars=>O
# organizer=>TITLE
# present=>DATE
# visit=>O
# appear=>O
# draw=>O
# little=>O
# response=>O
# appreciation=>O
# football=>O
# fan=>O
# country=>O
# one=>NUMBER
# reason=>O
# could=>O
# lack=>O
# international=>O
# exposure=>O
# national=>O
# team=>O
# player=>O
# presently=>O
# committee=>O
# FIFA=>ORGANIZATION
# manage=>O
# football=>O
# affair=>O
# country=>O
# want=>O
# contribute=>O
# football=>O
# Pakistan=>COUNTRY
# way=>O
# say=>O
# Kaka=>PERSON
# news=>O
# conference=>O
# Cristiano=>PERSON
# Ronaldo=>PERSON
# not=>O
# score=>O
# free-kick=>O
# almost=>O
# 2=>DURATION
# year=>DURATION
# Lionel=>PERSON
# Messi=>PERSON
# hit=>O
# two=>NUMBER
# single=>O
# game.comparison=>O
# Lionel=>PERSON
# Messi=>PERSON
# Cristiano=>PERSON
# Ronaldo=>PERSON
# refuse=>O
# die=>O
# superstar=>TITLE
# continue=>O
# talisman=>O
# team=>O
# however=>O
# last=>TIME
# night=>TIME
# messus=>O
# prove=>O
# one=>NUMBER
# thing=>O
# best=>O
# free-kick=>O
# taker=>O
# world=>O
# right=>O
# Barcelona=>ORGANIZATION
# poor=>O
# form=>O
# recently=>DATE
# messi=>O
# make=>O
# sure=>O
# club=>O
# stay=>O
# touch=>O
# distance=>O
# La=>ORGANIZATION
# Liga=>ORGANIZATION
# top=>O
# spot=>O
# messi=>O
# score=>O
# wonderful=>O
# hat-trick=>O
# Celta=>PERSON
# Vigo=>PERSON
# Camp=>PERSON
# Nou=>PERSON
# help=>O
# side=>O
# get=>O
# 4-1=>NUMBER
# win=>O
# La=>ORGANIZATION
# Liga=>ORGANIZATION
# along=>O
# way=>O
# messus=>O
# equal=>O
# Ronaldo=>PERSON
# record=>O
# hat-trick=>O
# La=>ORGANIZATION
# Liga=>ORGANIZATION
# history=>O
# 34=>NUMBER
# messus=>O
# score=>O
# two=>NUMBER
# free-kick=>O
# game=>O
# Barcelona=>ORGANIZATION
# stop=>O
# winless=>O
# streak=>O
# stroke=>CAUSE_OF_DEATH
# half-time=>O
# messi=>O
# score=>O
# sensational=>O
# free=>O
# kick=>O
# 25=>NUMBER
# yard=>O
# curl=>O
# wall=>O
# right=>O
# corner=>O
# goal-post=>O
# minute=>DATE
# later=>DATE
# messi=>O
# hit=>O
# another=>O
# free-kick=>O
# top=>O
# corner=>O
# complete=>O
# hat-trick=>O
# messus=>O
# hit=>O
# numerous=>O
# free-kick=>O
# recent=>O
# time=>O
# Ronaldo=>PERSON
# last=>O
# score=>O
# free-kick=>O
# 694=>DATE
# day=>DATE
# ago=>DATE
# messi=>O
# contract=>O
# expire=>O
# 2021=>DATE
# Barcelona=>ORGANIZATION
# president=>TITLE
# Josep=>PERSON
# Bartomeu=>PERSON
# reveal=>O
# club=>O
# offer=>O
# messi=>O
# lifetime=>O
# contract=>O
# see=>O
# career=>O
# Camp=>LOCATION
# Nou=>LOCATION
# next=>O
# two=>NUMBER
# three=>NUMBER
# season=>O
# leader=>TITLE
# continue=>O
# messi=>PERSON
# Bartomeu=>PERSON
# say=>O
# interview=>O
# Associated=>ORGANIZATION
# Press=>ORGANIZATION
# however=>O
# young=>O
# player=>O
# come=>O
# come=>O
# abroad=>O
# come=>O
# La=>PERSON
# Masia=>PERSON
# content=>O
# prepare=>O
# post-messi=>O
# era=>O
# I=>O
# always=>O
# make=>O
# comparison=>O
# pelé=>O
# explain=>O
# Bartomeu=>PERSON
# Pelé=>PERSON
# man=>O
# one=>NUMBER
# club=>O
# Brazil=>COUNTRY
# ...=>O
# I=>O
# no=>O
# doubt=>O
# messi=>O
# end=>O
# career=>O
# footballer=>TITLE
# remain=>O
# link=>O
# club=>O
# rest=>O
# life=>O
# bartomeu=>O
# insist=>O
# Leo=>PERSON
# Messi=>PERSON
# contract=>O
# end=>DATE
# 2021=>DATE
# go=>O
# surely=>O
# party=>O
# involve=>O
# feel=>O
# strong=>O
# ambitious=>O
# extend=>O
# contract=>O
# indefinitely=>O
# finish=>O
# Bartomeu=>ORGANIZATION
# emphatically=>O
# Barcelona=>ORGANIZATION
# offer=>O
# lifetime=>O
# contract=>O
# club=>O
# legend=>O
# Andres=>PERSON
# Iniesta=>PERSON
# 2017=>DATE
# month=>DURATION
# sign=>O
# Bayern=>ORGANIZATION
# brush=>O
# aside=>O
# off-field=>O
# woe=>O
# thrash=>O
# Dortmund=>ORGANIZATION
# Klassiker=>ORGANIZATION
# Managerless=>ORGANIZATION
# Bayern=>ORGANIZATION
# Munich=>ORGANIZATION
# thrash=>O
# borussia=>O
# dortmund=>O
# 4-0=>O
# der=>O
# Klassiker=>PERSON
# Robert=>PERSON
# Lewandowski=>PERSON
# continue=>O
# phenomenal=>O
# score=>O
# run=>O
# two=>NUMBER
# goal=>O
# Allianz=>ORGANIZATION
# Arena=>ORGANIZATION
# Lewandowski=>PERSON
# first-half=>O
# header=>TITLE
# 76th-minute=>O
# tap-in=>O
# mean=>O
# score=>O
# Bayern=>ORGANIZATION
# Bundesliga=>ORGANIZATION
# Champions=>ORGANIZATION
# League=>ORGANIZATION
# game=>O
# season=>O
# tally=>O
# 23=>NUMBER
# goal=>O
# Serge=>PERSON
# Gnabry=>PERSON
# claim=>O
# Bayern=>ORGANIZATION
# second=>ORDINAL
# visit=>O
# captain=>TITLE
# mat=>O
# hummel=>O
# score=>O
# late=>O
# goal=>O
# former=>O
# club=>O
# dortmund=>O
# suffer=>O
# another=>O
# heavy=>O
# defeat=>O
# Munich=>CITY
# also=>O
# lose=>O
# 5-0=>NUMBER
# April=>DATE
# Bayern=>ORGANIZATION
# move=>O
# third=>ORDINAL
# level=>O
# point=>O
# second-placed=>O
# rb=>O
# Leipzig=>CITY
# one=>NUMBER
# behind=>O
# leader=>TITLE
# borussia=>O
# moenchengladbach=>O
# host=>TITLE
# Werder=>ORGANIZATION
# Bremen=>ORGANIZATION
# Sunday=>ORGANIZATION
# Interim=>ORGANIZATION
# coach=>O
# Hansi=>PERSON
# flick=>O
# enjoy=>O
# second=>ORDINAL
# win=>O
# charge=>O
# since=>O
# Niko=>PERSON
# Kovac=>PERSON
# sack=>O
# last=>DATE
# Sunday=>DATE
# however=>O
# Bayern=>ORGANIZATION
# difficulty=>O
# find=>O
# new=>O
# coach=>TITLE
# Arsene=>PERSON
# Wenger=>PERSON
# Saturday=>DATE
# contradict=>O
# claim=>O
# turn=>O
# Kovac=>PERSON
# successor=>O
# slam=>O
# club=>O
# lack=>O
# discretion=>O
# Bayern=>ORGANIZATION
# chairman=>TITLE
# Karl-Heinz=>PERSON
# Rummenigge=>PERSON
# speak=>O
# Wenger=>PERSON
# last=>DATE
# week=>DATE
# cancel=>O
# pre-match=>O
# interview=>O
# sky=>O
# Ajax=>ORGANIZATION
# coach=>TITLE
# Erik=>PERSON
# ten=>NUMBER
# Hag=>ORGANIZATION
# Paris=>ORGANIZATION
# Saint-Germain=>ORGANIZATION
# boss=>TITLE
# Thomas=>PERSON
# Tuchel=>PERSON
# already=>O
# make=>O
# clear=>O
# not=>O
# join=>O
# Bayern=>ORGANIZATION
# season=>O
# despite=>O
# off-field=>O
# trouble=>O
# Bayern=>ORGANIZATION
# bounce=>O
# back=>O
# last=>DATE
# weekend=>DATE
# 5-1=>NUMBER
# drubbing=>O
# Eintracht=>PERSON
# Frankfurt=>PERSON
# Lewandowski=>PERSON
# score=>O
# superb=>O
# header=>TITLE
# Benjamin=>PERSON
# Pavard=>PERSON
# cross=>O
# 17=>DURATION
# minute=>DURATION
# dortmund=>O
# winger=>TITLE
# Jadon=>PERSON
# Sancho=>PERSON
# hook=>O
# 36=>DURATION
# minute=>DURATION
# fail=>O
# make=>O
# impact=>O
# proceedings=>O
# gnabry=>O
# goal=>O
# rule=>O
# offside=>O
# Bayern=>ORGANIZATION
# go=>O
# 1-0=>NUMBER
# break=>O
# Germany=>COUNTRY
# winger=>TITLE
# strike=>O
# two=>DURATION
# minute=>DURATION
# second=>ORDINAL
# half=>O
# Lewandowski=>PERSON
# stumble=>O
# goal=>O
# mercy=>O
# gnabry=>O
# fire=>CAUSE_OF_DEATH
# home=>O
# hour=>DURATION
# go=>O
# side=>O
# 2-0=>O
# dortmund=>O
# coach=>TITLE
# Lucien=>PERSON
# Favre=>PERSON
# bring=>O
# forwards=>O
# Marco=>PERSON
# Reus=>PERSON
# Paco=>PERSON
# Alcacer=>PERSON
# recover=>O
# foot=>O
# calf=>O
# injury=>O
# respectively=>O
# alcacer=>O
# head=>O
# hand=>O
# fail=>O
# connect=>O
# Achraf=>PERSON
# Hakimi=>PERSON
# cross=>O
# 20=>DURATION
# minute=>DURATION
# leave=>O
# Dortmund=>ORGANIZATION
# best=>O
# chance=>O
# go=>O
# beg=>O
# Bayern=>ORGANIZATION
# third=>ORDINAL
# come=>O
# lewandowski=>O
# finish=>O
# another=>O
# counter-attack=>O
# host=>TITLE
# hummel=>O
# goal=>O
# Leipzig=>CITY
# go=>O
# second=>DATE
# earlier=>DATE
# Timo=>PERSON
# Werner=>PERSON
# net=>O
# twice=>O
# Leipzig=>CITY
# go=>O
# second=>ORDINAL
# 4-2=>NUMBER
# win=>O
# Hertha=>LOCATION
# Berlin=>CITY
# capital=>O
# Berlin=>CITY
# Wall=>LOCATION
# fall=>DATE
# November=>DATE
# 9=>DATE
# 1989=>DATE
# mark=>O
# 30th=>ORDINAL
# anniversary=>O
# replica=>O
# wall=>O
# divide=>O
# Germany=>COUNTRY
# capital=>O
# 1961=>DATE
# separated=>O
# Hertha=>ORGANIZATION
# Leipzig=>ORGANIZATION
# knock=>O
# prior=>O
# kick-off=>O
# Midfielder=>TITLE
# Maximilian=>PERSON
# Mittelstaedt=>PERSON
# give=>O
# Hertha=>ORGANIZATION
# first-half=>O
# lead=>O
# last=>DATE
# six=>DATE
# minute=>DATE
# Werner=>PERSON
# convert=>O
# penalty=>O
# hat-trick=>O
# last=>DATE
# weekend=>DATE
# 8-0=>NUMBER
# thrashing=>O
# Mainz=>PERSON
# Marcel=>PERSON
# Sabitzer=>PERSON
# add=>O
# Leipzig=>CITY
# second=>ORDINAL
# stroke=>CAUSE_OF_DEATH
# half-time=>O
# three=>NUMBER
# goal=>O
# come=>O
# final=>O
# five=>DURATION
# minute=>DURATION
# Kevin=>PERSON
# Kampl=>PERSON
# net=>O
# Leipzig=>CITY
# third=>ORDINAL
# superb=>O
# left-footed=>O
# strike=>O
# Werner=>PERSON
# grab=>O
# second=>ORDINAL
# 11th=>ORDINAL
# league=>O
# goal=>O
# many=>O
# game=>O
# Hertha=>ORGANIZATION
# striker=>TITLE
# Davie=>PERSON
# Selke=>PERSON
# score=>O
# former=>O
# club=>O
# striker=>TITLE
# Rouwen=>PERSON
# Hennings=>PERSON
# complete=>O
# hat-trick=>O
# five=>DURATION
# minute=>DURATION
# time=>O
# Fortuna=>ORGANIZATION
# Duesseldorf=>ORGANIZATION
# hold=>O
# Schalke=>ORGANIZATION
# 3-3=>NUMBER
# draw=>O
# Royal=>ORGANIZATION
# Blues=>ORGANIZATION
# squander=>O
# lead=>O
# three=>NUMBER
# time=>O
# goal=>O
# Daniel=>PERSON
# Caligiuri=>PERSON
# Ozan=>PERSON
# Kabak=>PERSON
# Suat=>PERSON
# Serdar=>PERSON
# Gelsenkirchen=>PERSON
# cancel=>O
# Hennings=>LOCATION
# Union=>CITY
# Berlin=>CITY
# 11th=>ORDINAL
# third=>ORDINAL
# straight=>O
# win=>O
# Sebastian=>PERSON
# Anderson=>PERSON
# score=>O
# twice=>O
# 3-2=>NUMBER
# victory=>O
# Mainz=>CITY
# Augsburg=>CITY
# climb=>O
# bottom=>O
# three=>NUMBER
# 1-0=>NUMBER
# win=>O
# bottom=>O
# club=>O
# paderborn=>O
# Lionel=>PERSON
# Messi=>PERSON
# equal=>O
# Cristiano=>PERSON
# Ronaldo=>PERSON
# huge=>O
# La=>ORGANIZATION
# Liga=>ORGANIZATION
# record=>O
# hat-trick=>O
# despite=>O
# fact=>O
# former=>O
# real=>O
# Madrid=>CITY
# forward=>O
# Cristiano=>PERSON
# Ronaldo=>PERSON
# serie=>O
# club=>O
# juventus=>O
# since=>O
# July=>DATE
# 2018=>DATE
# rivalry=>O
# Barcelona=>ORGANIZATION
# star=>O
# forward=>O
# Lionel=>PERSON
# Messi=>PERSON
# continue=>O
# Saturday=>DATE
# Messi=>O
# register=>O
# hat-trick=>O
# Celta=>ORGANIZATION
# Vigo=>ORGANIZATION
# Camp=>ORGANIZATION
# Nou=>ORGANIZATION
# help=>O
# side=>O
# get=>O
# 4-1=>NUMBER
# win=>O
# La=>ORGANIZATION
# Liga=>ORGANIZATION
# match=>O
# messus=>O
# equalise=>O
# Ronaldo=>PERSON
# record=>O
# player=>O
# hat-trick=>O
# La=>ORGANIZATION
# Liga=>ORGANIZATION
# history=>O
# 34=>NUMBER
# argentine=>NATIONALITY
# forward=>O
# convert=>O
# kick=>O
# spot=>O
# 22nd=>DATE
# minute=>DATE
# get=>O
# goal=>O
# later=>O
# messus=>O
# take=>O
# sensational=>O
# free=>O
# kick=>O
# 25=>NUMBER
# yard=>O
# curl=>O
# wall=>O
# right=>O
# corner=>O
# goal-post=>O
# stroke=>CAUSE_OF_DEATH
# half=>O
# time=>O
# two=>DURATION
# minute=>DURATION
# second=>ORDINAL
# half=>O
# Barca=>ORGANIZATION
# star=>O
# convert=>O
# another=>O
# free-kick=>O
# similar=>O
# fashion=>O
# complete=>O
# hat-trick=>O
# Ronaldo=>PERSON
# no=>O
# longer=>O
# real=>O
# Madrid=>CITY
# highly=>O
# likely=>O
# messus=>O
# would=>O
# go=>O
# surpass=>O
# portuguese=>NATIONALITY
# international=>O
# stand=>O
# sole=>O
# top=>O
# spot=>O
# record=>O
# book=>O
# also=>O
# messi=>O
# 427th=>O
# goal=>O
# spanish=>NATIONALITY
# league=>O
# big=>O
# advantage=>O
# best=>O
# player=>O
# world=>O
# side=>O
# also=>O
# best=>O
# take=>O
# free=>O
# kick=>O
# Barcelona=>ORGANIZATION
# midfielder=>TITLE
# Sergio=>PERSON
# Busquets=>PERSON
# praise=>O
# messi=>O
# match=>O
# little=>O
# little=>O
# improve=>O
# free=>O
# kick=>O
# use=>O
# find=>O
# hard=>O
# around=>O
# give=>O
# real=>O
# boost=>O
# add=>O
# win=>O
# defend=>O
# spanish=>NATIONALITY
# Champions=>O
# reach=>O
# back=>O
# take=>O
# top=>O
# spot=>O
# table=>O
# tie=>O
# 25=>NUMBER
# point=>O
# real=>O
# Madrid=>CITY
# better=>O
# goal=>O
# difference=>O
# meanwhile=>O
# real=>O
# Madrid=>CITY
# pick=>O
# big=>O
# win=>O
# Saturday=>DATE
# defeat=>O
# Eibar=>PERSON
# away=>O
# game=>O
# brace=>O
# Karim=>PERSON
# Benzema=>PERSON
# goal=>O
# defender=>TITLE
# Sergi=>PERSON
# Ramos=>PERSON
# goal=>O
# Federico=>PERSON
# Valverde=>PERSON
# Premier=>TITLE
# League=>O
# Jamie=>PERSON
# Vardy=>PERSON
# James=>PERSON
# Maddison=>PERSON
# pull=>O
# Leicester=>CITY
# City=>LOCATION
# clear=>O
# arsenal.leicester=>O
# open=>O
# nine-point=>O
# lead=>O
# arsenal=>O
# battle=>O
# Champions=>MISC
# League=>MISC
# qualification=>O
# move=>O
# second=>ORDINAL
# Premier=>ORGANIZATION
# League=>ORGANIZATION
# 2-0=>NUMBER
# win=>O
# Gunners=>O
# Saturday=>DATE
# Jamie=>PERSON
# Vardy=>PERSON
# James=>PERSON
# Maddison=>PERSON
# architect=>TITLE
# another=>O
# fine=>O
# victory=>O
# Foxes=>MISC
# English=>NATIONALITY
# duo=>O
# strike=>O
# space=>O
# seven=>NUMBER
# second-half=>O
# minute=>DURATION
# arsenal=>O
# eight=>NUMBER
# point=>O
# adrift=>O
# top=>O
# four=>NUMBER
# fall=>DATE
# even=>O
# behind=>O
# Manchester=>ORGANIZATION
# City=>ORGANIZATION
# avoid=>O
# defeat=>O
# away=>O
# league=>O
# leader=>TITLE
# Liverpool=>ORGANIZATION
# Sunday=>ORGANIZATION
# face=>ORGANIZATION
# mount=>ORGANIZATION
# speculation=>O
# future=>DATE
# Emery=>PERSON
# surprisingly=>O
# maintain=>O
# Mesut=>PERSON
# Ozil=>PERSON
# alongside=>O
# front=>O
# two=>NUMBER
# new=>O
# captain=>TITLE
# Pierre-Emerick=>PERSON
# Aubameyang=>PERSON
# Alexandre=>PERSON
# Lacazette=>PERSON
# bold=>O
# strategy=>O
# nearly=>O
# pay=>O
# lacazette=>O
# fire=>CAUSE_OF_DEATH
# first=>ORDINAL
# big=>O
# chance=>O
# match=>O
# inch=>O
# wide=>O
# aubameyang=>O
# burrow=>O
# way=>O
# area=>O
# thereafter=>O
# Leicester=>CITY
# better=>O
# chance=>O
# break=>O
# deadlock=>O
# Vardy=>PERSON
# fail=>O
# connect=>O
# Ayoze=>O
# Perez=>O
# dangerous=>O
# cross=>O
# Maddison=>PERSON
# curl=>O
# free-kick=>O
# inch=>O
# wide=>O
# Wilfred=>PERSON
# Ndidi=>PERSON
# next=>O
# miss=>O
# glorious=>O
# chance=>O
# smash=>O
# crossbar=>O
# goal=>O
# gaping=>O
# Ricardo=>PERSON
# Pereira=>PERSON
# cutback=>O
# four=>DURATION
# minute=>DURATION
# second=>ORDINAL
# half=>O
# arsenal=>O
# first=>ORDINAL
# put=>O
# ball=>O
# net=>O
# aubameyang=>O
# supply=>O
# characteristically=>O
# clinical=>O
# finish=>O
# rightly=>O
# flag=>O
# offside=>O
# Vardy=>PERSON
# excellent=>O
# record=>O
# Arsenal=>O
# chance=>O
# come=>O
# Premier=>ORGANIZATION
# League=>ORGANIZATION
# top=>O
# scorer=>TITLE
# ruthless=>O
# low=>O
# finish=>O
# past=>DATE
# Bernd=>PERSON
# Leno=>PERSON
# Youri=>PERSON
# Tielemans=>PERSON
# pass=>O
# former=>O
# England=>COUNTRY
# striker=>TITLE
# turn=>O
# provider=>O
# lay=>O
# ball=>O
# back=>O
# path=>O
# maddison=>O
# drill=>O
# low=>O
# shot=>O
# outside=>O
# box=>O
# arsenal=>O
# offer=>O
# precious=>O
# little=>O
# go=>O
# behind=>O
# Tottenham=>ORGANIZATION
# slip=>O
# 12th=>ORDINAL
# hold=>O
# Sheffield=>ORGANIZATION
# United.Tottenham=>ORGANIZATION
# surrender=>O
# lead=>O
# third=>ORDINAL
# straight=>O
# Premier=>TITLE
# League=>O
# game=>O
# Sheffield=>ORGANIZATION
# United=>ORGANIZATION
# move=>O
# fifth=>ORDINAL
# thoroughly=>O
# deserve=>O
# 1-1=>NUMBER
# draw=>O
# Tottenham=>ORGANIZATION
# Hotspur=>ORGANIZATION
# Stadium=>O
# Saturday=>DATE
# Son=>O
# heung-min=>O
# strike=>O
# hour=>DURATION
# mark=>O
# threaten=>O
# get=>O
# Spurs=>ORGANIZATION
# jail=>O
# especially=>O
# controversial=>O
# var=>O
# rule=>O
# David=>PERSON
# McGoldrick=>PERSON
# equaliser=>O
# moment=>O
# later=>O
# George=>PERSON
# Baldock=>PERSON
# cross=>O
# find=>O
# way=>O
# Paulo=>PERSON
# Gazzaniga=>PERSON
# net=>O
# survive=>O
# var=>O
# review=>O
# level=>O
# 12=>DURATION
# minute=>DURATION
# time=>O
# tottenham=>O
# look=>O
# back=>O
# groove=>O
# sweep=>O
# aside=>O
# red=>O
# Star=>ORGANIZATION
# Belgrade=>ORGANIZATION
# 4-0=>O
# Champions=>MISC
# League=>MISC
# midweek=>O
# first=>ORDINAL
# away=>O
# win=>O
# competition=>O
# since=>O
# May=>DATE
# however=>O
# Pochettino=>PERSON
# man=>O
# fall=>O
# back=>O
# bad=>O
# habit=>O
# characterise=>O
# poor=>O
# Premier=>TITLE
# League=>MISC
# campaign=>O
# slip=>O
# 12th=>ORDINAL
# back=>O
# run=>O
# two=>NUMBER
# win=>O
# 11=>NUMBER
# game=>O
# Spurs=>ORGANIZATION
# defender=>TITLE
# Eric=>PERSON
# Dier=>PERSON
# book=>O
# 75=>DURATION
# seconds=>DURATION
# clatter=>O
# Baldock=>PERSON
# former=>O
# England=>COUNTRY
# international=>O
# lucky=>O
# not=>O
# send=>O
# inside=>O
# 20=>DURATION
# minute=>DURATION
# another=>O
# foul=>O
# McGoldrick=>PERSON
# Dier=>PERSON
# unease=>O
# show=>O
# throughout=>O
# disjointed=>O
# display=>O
# host=>TITLE
# lucky=>O
# escape=>CRIMINAL_CHARGE
# two=>NUMBER
# occasion=>O
# John=>PERSON
# Lundstrum=>PERSON
# fail=>O
# turn=>O
# home=>O
# dangerous=>O
# low=>O
# cross=>O
# box=>O
# midfielder=>TITLE
# smash=>O
# shoot=>O
# post=>O
# Son=>O
# free=>O
# play=>O
# red=>O
# card=>O
# incident=>O
# see=>O
# Everton=>PERSON
# Andre=>PERSON
# Gomes=>PERSON
# suffer=>O
# broken=>O
# ankle=>O
# last=>DATE
# weekend=>DATE
# rescind=>O
# south=>NATIONALITY
# korean=>NATIONALITY
# distance=>O
# Tottenham=>ORGANIZATION
# dangerous=>O
# player=>O
# force=>O
# Dean=>PERSON
# Henderson=>PERSON
# first=>ORDINAL
# serious=>O
# save=>O
# early=>DATE
# second=>DATE
# half=>DATE
# United=>ORGANIZATION
# start=>O
# game=>O
# joint=>O
# best=>O
# defensive=>O
# record=>O
# league=>O
# rare=>O
# slip=>O
# Enda=>PERSON
# Stevens=>PERSON
# present=>DATE
# Son=>O
# glorious=>O
# chance=>O
# deflect=>O
# shot=>O
# squeeze=>O
# Henderson=>PERSON
# leg=>O
# 129=>DATE
# seconds=>DATE
# later=>DATE
# United=>ORGANIZATION
# celebrate=>O
# equaliser=>O
# McGoldrick=>PERSON
# convert=>O
# Stevens=>PERSON
# cross=>O
# far=>O
# post=>O
# however=>O
# painstakingly=>O
# long=>O
# check=>O
# lundstram=>O
# toe=>O
# rule=>O
# offside=>O
# blade=>O
# get=>O
# slice=>O
# fortune=>O
# deserve=>O
# baldock=>O
# miscue=>O
# cross=>O
# end=>O
# bend=>O
# far=>O
# post=>O
# Spurs=>ORGANIZATION
# late=>O
# flurry=>O
# attempt=>O
# take=>O
# three=>NUMBER
# point=>O
# Henderson=>PERSON
# hand=>O
# tip=>O
# Lucas=>PERSON
# Moura=>PERSON
# effort=>O
# home=>O
# fan=>O
# roundly=>O
# b=>O
# Barcelona=>ORGANIZATION
# president=>TITLE
# reveal=>O
# club=>O
# prepare=>O
# post-Lionel=>O
# Messi=>O
# era.certainly=>O
# not=>O
# good=>O
# time=>O
# Barcelona=>ORGANIZATION
# Blaugurana=>ORGANIZATION
# struggle=>O
# fire=>CAUSE_OF_DEATH
# cylinder=>O
# La=>ORGANIZATION
# Liga=>ORGANIZATION
# well=>O
# Champions=>MISC
# League=>MISC
# look=>O
# towards=>O
# Lionel=>PERSON
# Messi=>PERSON
# answer=>O
# little=>O
# magician=>TITLE
# able=>O
# win=>O
# match=>O
# Catalans=>MISC
# thing=>O
# still=>O
# look=>O
# bleak=>O
# Barcelona=>ORGANIZATION
# defeat=>O
# Levante=>ORGANIZATION
# La=>ORGANIZATION
# Liga=>ORGANIZATION
# Slavia=>ORGANIZATION
# Praha=>ORGANIZATION
# earn=>O
# 0-0=>O
# draw=>O
# Camp=>O
# Nou=>O
# concern=>O
# report=>O
# messus=>O
# not=>O
# talk=>O
# term=>O
# new=>O
# signing=>O
# Antoine=>PERSON
# Griezmann=>PERSON
# speculation=>O
# regard=>O
# messi=>O
# future=>DATE
# Camp=>LOCATION
# Nou=>LOCATION
# also=>O
# five-time=>O
# Ballon=>PERSON
# winner=>O
# contract=>O
# expire=>O
# 2021=>DATE
# Barcelona=>ORGANIZATION
# president=>TITLE
# Josep=>PERSON
# Bartomeu=>PERSON
# reveal=>O
# club=>O
# offer=>O
# messi=>O
# lifetime=>O
# contract=>O
# see=>O
# career=>O
# Camp=>LOCATION
# Nou=>LOCATION
# next=>O
# two=>NUMBER
# three=>NUMBER
# season=>O
# leader=>TITLE
# continue=>O
# messi=>O
# Bartomeu=>PERSON
# tell=>O
# Associated=>ORGANIZATION
# Press=>ORGANIZATION
# however=>O
# young=>O
# player=>O
# come=>O
# come=>O
# abroad=>O
# come=>O
# La=>PERSON
# Masia=>PERSON
# content=>O
# prepare=>O
# post-messi=>O
# era=>O
# I=>O
# always=>O
# make=>O
# comparison=>O
# pelé=>O
# explain=>O
# Bartomeu=>ORGANIZATION
# Pelé=>ORGANIZATION
# man=>O
# one=>NUMBER
# club=>O
# Brazil=>COUNTRY
# ...=>O
# I=>O
# no=>O
# doubt=>O
# messi=>O
# end=>O
# career=>O
# footballer=>TITLE
# remain=>O
# link=>O
# club=>O
# rest=>O
# life=>O
# bartomeu=>O
# insist=>O
# Leo=>PERSON
# Messi=>PERSON
# contract=>O
# end=>DATE
# 2021=>DATE
# go=>O
# surely=>O
# party=>O
# involve=>O
# feel=>O
# strong=>O
# ambitious=>O
# extend=>O
# contract=>O
# indefinitely=>O
# Bartomeu=>ORGANIZATION
# conclude=>O
# Barcelona=>ORGANIZATION
# offer=>O
# lifetime=>O
# contract=>O
# club=>O
# legend=>O
# Andres=>PERSON
# Iniesta=>PERSON
# 2017=>DATE
# month=>DURATION
# sign=>O
# iniesta=>O
# move=>O
# japanese=>NATIONALITY
# side=>O
# Vissel=>LOCATION
# Kobe=>CITY
# look=>O
# highly=>O
# likely=>O
# messi=>O
# accept=>O
# contract=>O
# extension=>O
# move=>O
# ISL=>ORGANIZATION
# 2019=>DATE
# ATK=>ORGANIZATION
# crush=>O
# Jamshedpur=>CITY
# 3-1=>NUMBER
# climb=>O
# top=>O
# spot.two-time=>O
# former=>O
# champion=>O
# atk=>O
# continue=>O
# dream=>O
# run=>O
# beat=>O
# Jamshedpur=>ORGANIZATION
# FC=>ORGANIZATION
# 3-1=>NUMBER
# climb=>O
# top=>O
# indian=>NATIONALITY
# Super=>ORGANIZATION
# League=>ORGANIZATION
# ISL=>ORGANIZATION
# stand=>O
# Saturday=>DATE
# rain-hit=>O
# evening=>TIME
# cyclone=>O
# Bulbul=>MISC
# make=>O
# landfall=>O
# near=>O
# West=>LOCATION
# Bengal=>LOCATION
# coastline=>O
# home=>O
# side=>O
# dominate=>O
# proceedings=>O
# take=>O
# 2-0=>O
# lead=>O
# fijian=>NATIONALITY
# star=>O
# forward=>O
# Roy=>PERSON
# Krishna=>PERSON
# convert=>O
# spot=>O
# 57th=>ORDINAL
# 71st=>DATE
# minute=>DATE
# Sergio=>PERSON
# Castel=>PERSON
# reduce=>O
# margin=>O
# Jamshedpur=>ORGANIZATION
# FC=>ORGANIZATION
# 85th=>DATE
# minute=>DATE
# yet=>O
# another=>O
# penalty=>O
# Anas=>PERSON
# Edathodika=>PERSON
# bring=>O
# Noe=>PERSON
# Acosta=>PERSON
# ugly=>O
# challenge=>O
# inside=>O
# box=>O
# Castel=>O
# bury=>O
# ease=>O
# visitor=>O
# fail=>O
# equalise=>O
# Edu=>PERSON
# Garcia=>PERSON
# seal=>O
# deal=>O
# magnificent=>O
# finish=>O
# 90=>NUMBER
# +2=>NUMBER
# nd=>O
# minute=>DURATION
# Salt=>O
# Lake=>O
# Stadium=>O
# David=>PERSON
# Williams=>PERSON
# make=>O
# excellent=>O
# cross-field=>O
# ball=>O
# right=>O
# towards=>O
# Roy=>PERSON
# Krishna=>PERSON
# put=>O
# path=>O
# Garcia=>PERSON
# first=>ORDINAL
# touch=>O
# Garcia=>PERSON
# take=>O
# touch=>O
# get=>O
# close=>O
# goalkeeper=>TITLE
# chip=>O
# brilliantly=>O
# net=>O
# end=>O
# Jamshedpur=>CITY
# unbeaten=>O
# run=>O
# first=>ORDINAL
# away=>O
# match=>O
# season=>O
# Antonio=>PERSON
# Lopez=>PERSON
# habas-coached=>O
# side=>O
# endure=>O
# disappointing=>O
# start=>O
# lose=>O
# Kerala=>LOCATION
# 2-1=>NUMBER
# isl-6=>O
# opener=>TITLE
# thus=>O
# secure=>O
# hat-trick=>O
# win=>O
# thrash=>O
# Hyderabad=>CITY
# FC=>O
# 5-0=>NUMBER
# hard-fought=>O
# 1-0=>NUMBER
# away=>O
# win=>O
# Chennaiyin=>ORGANIZATION
# FC=>ORGANIZATION
# previous=>O
# match=>O
# Kolkata=>LOCATION
# franchise=>O
# nine=>NUMBER
# point=>O
# four=>NUMBER
# match=>O
# occupy=>O
# top=>O
# spot=>O
# ahead=>O
# FC=>ORGANIZATION
# Goa=>ORGANIZATION
# eight=>NUMBER
# point=>O
# Jamshedpur=>ORGANIZATION
# FC=>ORGANIZATION
# push=>O
# fourth=>ORDINAL
# place=>O
# seven=>NUMBER
# point=>O
# four=>NUMBER
# match=>O
# player=>O
# team=>O
# find=>O
# difficult=>O
# keep=>O
# balance=>O
# rain=>O
# incessantly=>O
# day=>DURATION
# atk=>O
# concede=>O
# one=>NUMBER
# chance=>O
# entire=>O
# half=>O
# biggest=>O
# game=>O
# Farukh=>O
# Choudhary=>O
# header=>TITLE
# come=>O
# crossbar=>O
# early=>DATE
# eighth=>DATE
# minute=>DATE
# except=>O
# ATK=>ORGANIZATION
# front-line=>O
# top-notch=>O
# put=>O
# immense=>O
# pressure=>O
# Subrata=>PERSON
# Paul=>PERSON
# charge=>O
# every=>O
# possible=>O
# opportunity=>O
# David=>PERSON
# Williams=>PERSON
# also=>O
# chance=>O
# 19th=>DATE
# minute=>DATE
# header=>TITLE
# go=>O
# wide=>O
# goal=>O
# Prabir=>PERSON
# Das=>PERSON
# right=>O
# Michael=>PERSON
# Soosairaj=>PERSON
# leave=>O
# keep=>O
# troubling=>O
# Jamshedpur=>CITY
# FC=>LOCATION
# along=>O
# miss=>O
# target=>O
# visitor=>O
# receive=>O
# setback=>O
# spanish=>NATIONALITY
# attack=>CAUSE_OF_DEATH
# mid-fielder=>O
# Piti=>PERSON
# limp=>O
# field=>O
# Noe=>PERSON
# Acosta=>PERSON
# replace=>O
# Chelsea=>PERSON
# go=>O
# second=>ORDINAL
# Premier=>TITLE
# League=>MISC
# sixth=>ORDINAL
# win=>O
# trot.chelsea=>O
# manager=>TITLE
# Frank=>PERSON
# Lampard=>PERSON
# insist=>O
# side=>O
# target=>O
# still=>O
# reduce=>O
# gap=>O
# title=>O
# favourite=>O
# liverpool=>O
# Manchester=>CITY
# City=>LOCATION
# despite=>O
# leapfrog=>O
# City=>O
# second=>ORDINAL
# place=>O
# sixth=>ORDINAL
# straight=>O
# Premier=>ORGANIZATION
# League=>ORGANIZATION
# win=>O
# Saturday=>DATE
# in-form=>O
# Tammy=>PERSON
# Abraham=>PERSON
# Christian=>PERSON
# pulisic=>O
# strike=>O
# second=>ORDINAL
# half=>O
# beat=>O
# Crystal=>ORGANIZATION
# Palace=>ORGANIZATION
# 2-0=>NUMBER
# Stamford=>CITY
# Bridge=>LOCATION
# Chelsea=>CITY
# edge=>O
# point=>O
# clear=>O
# city=>O
# within=>O
# five=>NUMBER
# leader=>TITLE
# Liverpool=>CITY
# host=>TITLE
# city=>O
# highly-anticipated=>O
# clash=>O
# Sunday=>DATE
# respect=>O
# Liverpool=>CITY
# Manchester=>CITY
# City=>LOCATION
# gap=>O
# try=>O
# bridge=>O
# way=>O
# go=>O
# season=>O
# Lampard=>PERSON
# tell=>O
# BT=>ORGANIZATION
# Sport=>ORGANIZATION
# possibility=>O
# title=>O
# challenge=>O
# happy=>O
# 4-4=>NUMBER
# draw=>O
# ajax=>O
# Tuesday=>DATE
# take=>O
# tally=>O
# goal=>O
# Chelsea=>ORGANIZATION
# prior=>O
# 18=>NUMBER
# game=>O
# season=>O
# 70=>NUMBER
# average=>O
# nearly=>O
# four=>NUMBER
# per=>O
# game=>O
# however=>O
# Blues=>O
# free=>O
# flow=>O
# football=>O
# meet=>O
# brick=>O
# wall=>O
# palace=>O
# defence=>O
# first=>ORDINAL
# 45=>DURATION
# minute=>DURATION
# I=>O
# little=>O
# bit=>O
# frustrated=>O
# I=>O
# feel=>O
# allow=>O
# tempo=>O
# drop=>O
# first=>ORDINAL
# half=>O
# add=>O
# Lampard=>PERSON
# I=>O
# feel=>O
# increase=>O
# tempo=>O
# game=>O
# win=>O
# pulisic=>O
# score=>O
# four=>NUMBER
# goal=>O
# last=>O
# two=>NUMBER
# Premier=>ORGANIZATION
# League=>ORGANIZATION
# game=>O
# american=>NATIONALITY
# begin=>O
# deliver=>O
# £=>MONEY
# 58=>MONEY
# million=>MONEY
# 74=>MONEY
# million=>MONEY
# price=>O
# tag=>O
# fine=>O
# save=>O
# Vicente=>PERSON
# Guaita=>PERSON
# deny=>O
# USA=>ORGANIZATION
# captain=>TITLE
# another=>O
# strike=>O
# early=>O
# thereafter=>O
# Chelsea=>PERSON
# largely=>O
# restricted=>O
# effort=>O
# free-kick=>O
# edge=>O
# box=>O
# break=>O
# willian=>O
# curl=>O
# inch=>O
# wide=>O
# Gary=>PERSON
# Cahill=>PERSON
# make=>O
# return=>O
# Stamford=>CITY
# Bridge=>LOCATION
# seven=>DURATION
# year=>DURATION
# Chelsea=>ORGANIZATION
# player=>O
# come=>O
# end=>DATE
# summer=>DATE
# Cahill=>PERSON
# remind=>O
# former=>O
# employer=>O
# win=>O
# eight=>NUMBER
# trophy=>O
# club=>O
# brilliant=>O
# block=>O
# repel=>O
# willian=>O
# goalbound=>O
# effort=>O
# first=>ORDINAL
# half=>O
# stoppage=>O
# time=>O
# palace=>O
# resistence=>O
# finally=>O
# break=>O
# one=>NUMBER
# moment=>O
# genius=>O
# Willian=>PERSON
# Chelsea=>PERSON
# captain=>TITLE
# day=>DURATION
# flick=>O
# ball=>O
# perfectly=>O
# Abraham=>PERSON
# path=>O
# slot=>O
# home=>O
# 10th=>ORDINAL
# Premier=>TITLE
# League=>O
# goal=>O
# season=>O
# join=>O
# Leicester=>PERSON
# Jamie=>PERSON
# Vardy=>PERSON
# top=>O
# scorer=>TITLE
# division=>O
# Abraham=>PERSON
# one=>NUMBER
# host=>TITLE
# youngster=>O
# shine=>O
# since=>O
# hand=>O
# chance=>O
# first=>ORDINAL
# team=>O
# lampard=>O
# number=>O
# nine=>NUMBER
# Chelsea=>ORGANIZATION
# world=>O
# class=>O
# striker=>TITLE
# I=>O
# feel=>O
# ready=>O
# I=>O
# proud=>O
# say=>O
# Abraham=>PERSON
# Pulisic=>PERSON
# test=>O
# Guaita=>LOCATION
# rise=>O
# drive=>O
# shortly=>O
# spaniard=>O
# brilliantly=>O
# tip=>O
# guaita=>O
# helpless=>O
# 11=>DURATION
# minute=>DURATION
# time=>O
# pulisic=>O
# finally=>O
# get=>O
# goal=>O
# performance=>O
# deserve=>O
# follow=>O
# Michy=>PERSON
# Batsh=>PERSON
# Manchester=>CITY
# City=>LOCATION
# goalkeeper=>TITLE
# Ederson=>ORGANIZATION
# Liverpool=>ORGANIZATION
# clash=>O
# say=>O
# pep=>O
# Guardiola.Manchester=>O
# City=>O
# keeper=>O
# Ederson=>PERSON
# miss=>O
# Sunday=>ORGANIZATION
# Premier=>ORGANIZATION
# League=>ORGANIZATION
# match=>O
# leader=>TITLE
# Liverpool=>ORGANIZATION
# due=>O
# muscle=>O
# injury=>O
# Claudio=>PERSON
# Bravo=>PERSON
# set=>O
# replace=>O
# goal=>O
# manager=>TITLE
# Pep=>PERSON
# Guardiola=>PERSON
# say=>O
# Friday=>DATE
# Ederson=>O
# lead=>O
# Premier=>ORGANIZATION
# League=>ORGANIZATION
# five=>NUMBER
# clean=>O
# sheet=>O
# season=>O
# force=>O
# halftime=>O
# Wednesday=>DATE
# 1-1=>NUMBER
# Champions=>MISC
# League=>MISC
# draw=>O
# Atalanta=>ORGANIZATION
# brazilian=>NATIONALITY
# see=>O
# walk=>O
# limp=>O
# game=>O
# Bravo=>O
# send=>O
# late=>O
# game=>O
# force=>O
# City=>O
# play=>O
# defender=>TITLE
# Kyle=>PERSON
# Walker=>PERSON
# goal=>O
# final=>O
# 10=>DURATION
# minute=>DURATION
# Guardiola=>PERSON
# say=>O
# trust=>O
# experienced=>O
# chilean=>NATIONALITY
# deliver=>O
# top-of-the-table=>O
# clash=>O
# Ederson=>O
# not=>O
# able=>O
# play=>O
# Sunday=>DATE
# another=>O
# top=>O
# goalkeeper=>TITLE
# Claudio=>PERSON
# Bravo=>PERSON
# Guardiola=>PERSON
# tell=>O
# reporter=>TITLE
# win=>O
# Carabao=>MISC
# Cup=>MISC
# FA=>MISC
# Cup=>MISC
# thanks=>O
# Claudio=>PERSON
# Bravo=>PERSON
# exceptional=>O
# goalkeeper=>TITLE
# ...=>O
# international=>O
# goalkeeper=>TITLE
# I=>O
# no=>O
# doubt=>O
# I=>O
# see=>O
# every=>SET
# day=>SET
# training=>O
# not=>O
# lose=>O
# Claudio=>PERSON
# red=>O
# card=>O
# day=>DURATION
# lose=>O
# ball=>O
# respect=>O
# guy=>O
# incredible=>O
# top=>O
# goalkeeper=>TITLE
# Liverpool=>ORGANIZATION
# City=>ORGANIZATION
# play=>O
# goalless=>O
# draw=>O
# Anfield=>ORGANIZATION
# last=>O
# season=>O
# though=>O
# question=>O
# Guardiola=>LOCATION
# City=>LOCATION
# defensive=>O
# mindset=>O
# say=>O
# consequence=>O
# adapt=>O
# Liverpool=>ORGANIZATION
# strategy=>O
# sometimes=>O
# want=>O
# adapt=>O
# team=>O
# good=>O
# Liverpool=>O
# Guardiola=>PERSON
# say=>O
# sometimes=>O
# people=>O
# recognise=>O
# play=>O
# champion=>O
# Europe=>LOCATION
# defensive=>O
# not=>O
# plan=>O
# good=>O
# push=>O
# deep=>O
# everything=>O
# well=>O
# see=>O
# team=>O
# weak=>O
# point=>O
# real=>O
# complete=>O
# team=>O
# need=>O
# kind=>O
# rival=>O
# win=>O
# Liverpool=>ORGANIZATION
# see=>O
# extend=>O
# lead=>O
# defend=>O
# champion=>O
# nine=>NUMBER
# point=>O
# Guardiola=>PERSON
# say=>O
# case=>O
# would=>O
# become=>O
# tougher=>O
# reel=>O
# Juergen=>PERSON
# Klopp=>PERSON
# side=>O
# lose=>O
# one=>NUMBER
# game=>O
# last=>O
# season=>O
# I=>O
# think=>O
# November=>DATE
# title=>O
# race=>O
# never=>O
# end=>O
# add=>O
# I=>O
# know=>O
# go=>O
# happen=>O
# lose=>O
# ...=>O
# I=>O
# think=>O
# lot=>O
# game=>O
# play=>O
# lot=>O
# difficult=>O
# course=>O
# see=>O
# Liverpool=>ORGANIZATION
# lose=>O
# one=>NUMBER
# game=>O
# last=>O
# season=>O
# season=>O
# unbeaten=>O
# imagine=>O
# think=>O
# not=>O
# go=>O
# lose=>O
# many=>O
# game=>O
# Klopp=>PERSON
# take=>O
# team=>O
# not=>O
# real=>O
# contender=>O
# win=>O
# Premier=>ORGANIZATION
# League=>ORGANIZATION
# --=>O
# three=>NUMBER
# four=>DURATION
# year=>DURATION
# Kerala=>ORGANIZATION
# Blasters=>ORGANIZATION
# Odisha=>ORGANIZATION
# FC=>ORGANIZATION
# settle=>O
# point=>O
# injury=>O
# take=>O
# toll.kerala=>O
# blaster=>TITLE
# FC=>ORGANIZATION
# remain=>O
# without=>O
# win=>O
# third=>ORDINAL
# consecutive=>O
# match=>O
# indian=>NATIONALITY
# Super=>ORGANIZATION
# League=>ORGANIZATION
# ISL=>ORGANIZATION
# follow=>O
# goalless=>O
# draw=>O
# Odisha=>ORGANIZATION
# FC=>ORGANIZATION
# Jawaharlal=>ORGANIZATION
# Nehru=>ORGANIZATION
# Stadium=>ORGANIZATION
# Friday=>DATE
# contest=>O
# mar=>DATE
# injury=>O
# key=>O
# player=>O
# team=>O
# Jairo=>PERSON
# Rodriguez=>PERSON
# Raphael=>PERSON
# Messi=>PERSON
# Bouli=>PERSON
# Aridane=>PERSON
# Santana=>PERSON
# substitute=>O
# first=>ORDINAL
# half=>O
# change=>O
# affect=>O
# pace=>O
# game=>O
# ultimately=>O
# end=>O
# without=>O
# winner=>O
# blaster=>TITLE
# odisha=>O
# four=>NUMBER
# point=>O
# many=>O
# game=>O
# occupy=>O
# fifth=>ORDINAL
# sixth=>ORDINAL
# position=>O
# league=>O
# table=>O
# respectively=>O
# Blasters=>O
# already=>O
# hamper=>O
# injury=>O
# season=>O
# suffer=>O
# major=>O
# blow=>O
# fourth=>DATE
# minute=>DATE
# captain=>TITLE
# Jairo=>PERSON
# Rodriguez=>PERSON
# go=>O
# injure=>O
# replace=>O
# Abdul=>PERSON
# Hakku=>PERSON
# however=>O
# home=>O
# side=>O
# continue=>O
# press=>O
# high=>O
# field=>O
# try=>O
# take=>O
# game=>O
# opponent=>O
# Odisha=>ORGANIZATION
# well=>O
# organise=>O
# back=>O
# cautious=>O
# period=>O
# play=>O
# early=>O
# come=>O
# halt=>O
# head-on=>O
# collision=>O
# inside=>O
# box=>O
# follow=>O
# corner-kick=>O
# leave=>O
# Aridane=>LOCATION
# Santana=>CITY
# Messi=>LOCATION
# Bouli=>LOCATION
# require=>O
# medical=>O
# attention=>O
# follow=>O
# long=>O
# pause=>O
# game=>O
# resume=>O
# Mohammed=>PERSON
# Rafi=>PERSON
# Carlos=>PERSON
# Delgado=>PERSON
# replace=>O
# injured=>O
# player=>O
# team=>O
# struggle=>O
# create=>O
# clear-cut=>O
# chance=>O
# Sahal=>PERSON
# Abdul=>PERSON
# Samad=>PERSON
# take=>O
# matter=>O
# hand=>O
# embark=>O
# stellar=>O
# solo=>O
# run=>O
# pick=>O
# ball=>O
# right=>O
# flank=>O
# midfielder=>TITLE
# outfox=>O
# three=>NUMBER
# defender=>TITLE
# Narayan=>PERSON
# Das=>PERSON
# bring=>O
# inside=>O
# box=>O
# referee=>TITLE
# reject=>O
# vociferous=>O
# appeal=>O
# penalty=>O
# blaster=>TITLE
# better=>O
# side=>O
# first=>ORDINAL
# half=>O
# although=>O
# fine=>O
# margin=>O
# Mohammed=>PERSON
# Rafi=>PERSON
# drill=>O
# cross=>O
# box=>O
# right=>O
# meet=>O
# rahul=>O
# kp=>O
# whose=>O
# audacious=>O
# volley=>O
# fail=>O
# test=>O
# goalkeeper=>TITLE
# Francisco=>PERSON
# Dorronsoro=>PERSON
# team=>O
# struggle=>O
# raise=>O
# tempo=>O
# keep=>O
# hold=>O
# ball=>O
# break=>O
# well=>O
# odisha=>O
# threaten=>O
# Jerry=>PERSON
# Mawihmingthanga=>PERSON
# cross=>O
# put=>O
# T.P.=>ORGANIZATION
# Rehenesh=>ORGANIZATION
# spot=>O
# bother=>O
# goalkeeper=>TITLE
# spill=>O
# ball=>O
# inside=>O
# box=>O
# Nandhakumar=>O
# Sekar=>O
# hit=>O
# rebound=>O
# side-netting=>O
# couple=>O
# chance=>O
# either=>O
# end=>O
# game=>O
# wound=>O
# goal=>O
# remain=>O
# elusive=>O
# four=>DURATION
# minute=>DURATION
# leave=>O
# prasanth=>O
# cross=>O
# leave=>O
# flick=>O
# towards=>O
# far=>O
# post=>O
# second-half=>O
# substitute=>O
# Bartholomew=>ORGANIZATION
# Ogbeche=>ORGANIZATION
# Rahul=>ORGANIZATION
# whose=>O
# firm=>O
# shot=>O
# keep=>O
# Dorronsoro=>PERSON
# Daniel=>PERSON
# Lalhlimpuia=>PERSON
# end=>O
# spurn=>O
# chance=>O
# ibrahimovic=>O
# set=>O
# ac=>O
# Milan=>CITY
# return=>O
# say=>O
# MLS=>O
# chief.Zlatan=>O
# Ibrahimovic=>PERSON
# set=>O
# rejoin=>O
# italian=>NATIONALITY
# side=>O
# ac=>ORGANIZATION
# Milan=>ORGANIZATION
# successful=>O
# stint=>O
# LA=>ORGANIZATION
# Galaxy=>ORGANIZATION
# Major=>ORGANIZATION
# League=>ORGANIZATION
# Soccer=>ORGANIZATION
# Commissioner=>O
# Don=>PERSON
# Garber=>PERSON
# say=>O
# 38-year-old=>DURATION
# swedish=>NATIONALITY
# striker=>TITLE
# spend=>O
# past=>DATE
# 18=>DURATION
# month=>DURATION
# MLS=>ORGANIZATION
# contract=>O
# galaxy=>O
# expire=>O
# end=>O
# year=>DURATION
# link=>O
# host=>TITLE
# european=>NATIONALITY
# club=>O
# Ibrahimovic=>PERSON
# play=>O
# Milan=>O
# 2010=>DATE
# 2012=>DATE
# score=>DATE
# 42=>DATE
# goal=>O
# 61=>NUMBER
# league=>O
# appearance=>O
# Garber=>PERSON
# say=>O
# way=>O
# back=>O
# Serie=>O
# a.=>O
# Zlatan=>PERSON
# interesting=>O
# guy=>O
# tell=>O
# ESPN=>ORGANIZATION
# keep=>O
# hand=>O
# full=>O
# inbox=>O
# full=>O
# thrill-a-minute=>O
# 38-year-old=>DURATION
# guy=>O
# recruit=>O
# ac=>ORGANIZATION
# Milan=>ORGANIZATION
# one=>NUMBER
# top=>O
# club=>O
# world=>O
# ibrahamovic=>O
# name=>O
# MLS=>ORGANIZATION
# best=>O
# xi=>O
# 2018=>DATE
# 2019=>DATE
# net=>O
# 53=>NUMBER
# goal=>O
# competition=>O
# season=>O
# galaxy=>O
# end=>O
# suffer=>O
# 5-3=>O
# defeat=>O
# local=>O
# rival=>O
# Los=>ORGANIZATION
# Angeles=>ORGANIZATION
# Football=>ORGANIZATION
# Club=>ORGANIZATION
# MLS=>ORGANIZATION
# Cup=>O
# W=>O
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-40-c44973de69f9> in <module>
#       1 for i in range(0, df.last_valid_index()+1):
# ----> 2     ner_corenlp(nlp, sentence=news_df2.iloc[i]['clean_text'])
#       3     #ner_corenlp(conn_nlp=nlp, sentence=df.iloc[i]['Text'])
#
# <ipython-input-39-51a2e4251f32> in ner_corenlp(conn_nlp, sentence)
#       7
#       8     parsed_str = conn_nlp.annotate(sentence, properties=props)
# ----> 9     parsed_dict = json.loads(parsed_str)
#      10     for sents in parsed_dict["sentences"]:
#      11             for word in sents["tokens"]:
#
# ~\Anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# ~\Anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~\Anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
def sentiment_corenlp(conn_nlp, sentence):
    props = {
        'annotators': 'sentiment',
        'pipelineLanguage': 'en',
        'outputFormat': 'json'
    }
    parsed_str = conn_nlp.annotate(sentence, properties=props)
    parsed_dict = json.loads(parsed_str)
    for sents in parsed_dict["sentences"]:
        print ( " ".join([word["word"] for word in sents["tokens"]]) + " => " \
            + str(sents["sentimentValue"]) + " = "+ sents["sentiment"])

# %%
for i in range(0, df.last_valid_index()+1):
    print(sentiment_corenlp(nlp, sentence=df.iloc[i]['Title']))
# Out:
# defend champ Bengaluru FC play goalless draw with NorthEast United FC in ISL opener => 1 = Negative
# None
# Mauricio Pochettino not go grey over Tottenham speculation => 2 = Neutral
# None
# Juergen Klopp criticise var after Liverpool draw at man United => 1 = Negative
# None
# Manchester City not ready to win Champions League Pep Guardiola => 2 = Neutral
# None
# Tottenham face with fresh Champions League rescue mission => 3 = Positive
# None
# Serie A Parachutist gatecrash Inter Milan 's win at Sassuolo Watch video => 1 = Negative
# None
# Zinedine Zidane shelf league intention as Madrid shift focus to Europe => 1 = Negative
# None
# Ogbeche the hero as Kerala Blasters strike down ATK in ISL opener => 1 = Negative
# None
# Liverpool strike late but win run end in 1-1 draw at Manchester United => 1 = Negative
# None
# no pressure of be defend champion Bengaluru FC coach => 1 = Negative
# None
# Bayern Munich slip up again as Augsburg grab last-gasp leveller => 1 = Negative
# None
# Premier League Tottenham stumble again as Chelsea Leicester win => 2 = Neutral
# None
# La Liga Messi Suarez Griezmann all on target as Barcelona dispatch Eibar => 1 = Negative
# None
# Premier League Everton beat West Ham to ease pressure on Marco Silva => 1 = Negative
# None
# Heart condition cloud young Anwar Ali 's football career => 2 = Neutral
# None
