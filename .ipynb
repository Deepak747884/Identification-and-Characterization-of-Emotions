# %%
import feedparser as fp
import json
import newspaper
from newspaper import Article
from time import mktime
from datetime import datetime
import csv

# %%
# Set the limit for number of articles to download
LIMIT = 50

data = {}
data['newspapers'] = {}

# load newspaper
with open('company.json') as data_file:
    companies = json.load(data_file)

articles_array = []    
    
count = 1
# Iterate through each news company
for company, value in companies.items():
    if 'rss' in value:
        d = fp.parse(value['rss'])
        print("Downloading articles from ", company)
        newsPaper = {
            "rss": value['rss'],
            #"link": value['link'],
            "articles": []
        }
        for entry in d.entries:
            # Check if publish date is provided, if no the article is skipped.
            # This is done to keep consistency in the data and to keep the script from crashing.
            if hasattr(entry, 'published'):
                if count > LIMIT:
                    break
                article = {}
                article['link'] = entry.link
                date = entry.published_parsed
                article['published'] = datetime.fromtimestamp(mktime(date)).isoformat()
                try:
                    content = Article(entry.link)
                    content.download()
                    content.parse()
                except Exception as e:
                    # If the download for some reason fails (ex. 404) the script will continue downloading
                    # the next article.
                    print(e)
                    print("continuing...")
                    continue
                article['title'] = content.title
                article['text'] = content.text
                article['authors'] = content.authors
                article['top_image'] =  content.top_image
                article['movies'] = content.movies
                newsPaper['articles'].append(article)
                articles_array.append(article)
                print(count, "articles downloaded from", company, ", url: ", entry.link)
                count = count + 1
    else:
        # This is the fallback method if a RSS-feed link is not provided.
        # It uses the python newspaper library to extract articles
        print("Building site for ", company)
        paper = newspaper.build(value['link'], memoize_articles=False)
        newsPaper = {
            "link": value['link'],
            "articles": []
        }
        noneTypeCount = 0
        for content in paper.articles:
            if count > LIMIT:
                break
            try:
                content.download()
                content.parse()
            except Exception as e:
                print(e)
                print("continuing...")
                continue
            # Again, for consistency, if there is no found publish date the article will be skipped.

            article = {}
            article['title'] = content.title
            article['authors'] = content.authors
            article['text'] = content.text
            article['top_image'] =  content.top_image
            article['movies'] = content.movies
            article['link'] = content.url
            article['published'] = content.publish_date
            newsPaper['articles'].append(article)
            articles_array.append(article)
            print(count, "articles downloaded from", company, " using newspaper, url: ", content.url)
            count = count + 1
            #noneTypeCount = 0
    count = 1
    data['newspapers'][company] = newsPaper
    
# Finally it saves the articles as a JSON-file.
try:
    f = csv.writer(open('Scraped_data_news_output.csv', 'w', encoding='utf-8'))
    f.writerow(['Title', 'Authors','Text','Image','Videos','Link','Published_Date'])
    #print(article)
    for artist_name in articles_array:
        title = artist_name['title']
        authors=artist_name['authors']
        text=artist_name['text']
        image=artist_name['top_image']
        video=artist_name['movies']
        link=artist_name['link']
        publish_date=artist_name['published']
        # Add each artist’s name and associated link to a row
        f.writerow([title, authors, text, image, video, link, publish_date])

except Exception as e: print(e)
# Out:
# Downloading articles from  HT
# 1 articles downloaded from HT , url:  https://www.hindustantimes.com/football/kolkata-in-race-to-host-india-qatar-world-cup-qualifier-in-march/story-VFQL7RbhSjpfv5a6X6MVLI.html
# 2 articles downloaded from HT , url:  https://www.hindustantimes.com/football/manchester-united-will-reinforce-squad-in-january-ole-gunnar-solskjaer/story-tH7dG6Wbx1kYf3C7ZYkeQI.html
# 3 articles downloaded from HT , url:  https://www.hindustantimes.com/football/arsenal-s-mesut-ozil-recalls-terrifying-car-jacking-ordeal/story-zzmRfs4lRq1BXxlLAin5kI.html
# 4 articles downloaded from HT , url:  https://www.hindustantimes.com/football/lionel-messi-wins-sixth-golden-shoe-award/story-pK7imiUxPxvKIeuETEtpsN.html
# 5 articles downloaded from HT , url:  https://www.hindustantimes.com/football/liverpool-head-to-united-with-widest-gulf-in-years/story-nN3vM5Rtfbxh0g2IcDtqxL.html
# 6 articles downloaded from HT , url:  https://www.hindustantimes.com/football/manchester-city-s-sergio-aguero-unhurt-after-car-crash-report/story-dSCGUqxba8S5bu4FHUMjSK.html
# 7 articles downloaded from HT , url:  https://www.hindustantimes.com/football/bulgaria-police-hold-six-over-racist-abuse-at-england-match/story-TfXU61VRJn5eFfsiWWHICK.html
# 8 articles downloaded from HT , url:  https://www.hindustantimes.com/football/barcelona-s-lionel-messi-receives-record-sixth-european-golden-shoe/story-JeB6V6cpYVDEJlbwvLDQwI.html
# 9 articles downloaded from HT , url:  https://www.hindustantimes.com/football/real-madrid-vs-barcelona-la-liga-wants-el-clasico-switched-to-madrid-over-catalan-protests/story-DfstGjrEoCbc03rYsjF10L.html
# 10 articles downloaded from HT , url:  https://www.hindustantimes.com/football/bangladesh-draw-unfortunate-team-will-learn-from-this-bhaichung-bhutia/story-1TDjccsCUkM42M7v5MQf6N.html
# 11 articles downloaded from HT , url:  https://www.hindustantimes.com/football/lazio-hit-with-stand-closure-for-celtic-game-over-racist-behaviour/story-3GScPCHNV59LKgbtS2TMaL.html
# 12 articles downloaded from HT , url:  https://www.hindustantimes.com/football/india-s-performance-was-no-match-to-atmosphere-at-salt-lake-sunil-chhetri/story-lZs4MxFg5gx4Ab0vPSQuaK.html
# 13 articles downloaded from HT , url:  https://www.hindustantimes.com/football/igor-stimac-rues-his-players-inability-to-score-goals/story-9DPymm3qvBB9C15gFyKOfI.html
# 14 articles downloaded from HT , url:  https://www.hindustantimes.com/football/spain-make-euro-2020-with-late-sweden-draw-beaten-ireland-forced-to-wait/story-tN6JLfF2UtkfF3sZoxLogL.html
# 15 articles downloaded from HT , url:  https://www.hindustantimes.com/football/god-man-superman-finding-maradona-in-naples/story-pj4WVXlvNTynzrX1U4xBEI.html

# %%
import pandas as pd

# %%
df_articles = pd.read_csv('Scraped_data_news_output.csv')

# %%
df_articles
# Out:
#                                                 Title  \
# 0   Kolkata in race to host India-Qatar World Cup ...
# 1   Manchester United will reinforce squad in Janu...
# 2   Arsenal’s Mesut Ozil recalls terrifying car-ja...
# 3           Lionel Messi wins sixth Golden Shoe award
# 4   Liverpool head to United with widest gulf in y...
# 5   Manchester City’s Sergio Aguero unhurt after c...
# 6   Bulgaria police hold six over racist abuse at ...
# 7   Barcelona’s Lionel Messi receives record sixth...
# 8   Real Madrid vs Barcelona: La Liga wants El Cla...
# 9   ‘Bangladesh draw unfortunate, team will learn ...
# 10  Lazio hit with stand closure for Celtic game o...
# 11  ‘India’s performance was no match to atmospher...
# 12  Igor Stimac rues his players’ inability to sco...
# 13  Spain make Euro 2020 with late Sweden draw, be...
# 14     God, man, superman: Finding Maradona in Naples
#
#                         Authors  \
# 0   ['Indo Asian News Service']
# 1                            []
# 2      ['Agence France-Presse']
# 3   ['Indo Asian News Service']
# 4                            []
# 5                            []
# 6                            []
# 7                            []
# 8                            []
# 9   ['Indo Asian News Service']
# 10                           []
# 11     ['Press Trust Of India']
# 12                           []
# 13                           []
# 14            ['Dhiman Sarkar']
#
#                                                  Text  \
# 0   football\r\n\r\nUpdated: Oct 17, 2019 19:49 IS...
# 1   football\r\n\r\nUpdated: Oct 17, 2019 19:49 IS...
# 2   football\r\n\r\nUpdated: Oct 17, 2019 17:33 IS...
# 3   football\r\n\r\nUpdated: Oct 17, 2019 13:19 IS...
# 4   football\r\n\r\nUpdated: Oct 17, 2019 12:26 IS...
# 5   football\r\n\r\nUpdated: Oct 17, 2019 12:26 IS...
# 6   football\r\n\r\nUpdated: Oct 16, 2019 21:43 IS...
# 7   football\r\n\r\nUpdated: Oct 16, 2019 20:59 IS...
# 8   football\r\n\r\nUpdated: Oct 16, 2019 18:10 IS...
# 9   football\r\n\r\nUpdated: Oct 16, 2019 16:14 IS...
# 10  football\r\n\r\nUpdated: Oct 16, 2019 15:10 IS...
# 11  football\r\n\r\nUpdated: Oct 16, 2019 10:44 IS...
# 12  football\r\n\r\nUpdated: Oct 16, 2019 10:20 IS...
# 13  football\r\n\r\nUpdated: Oct 16, 2019 10:05 IS...
# 14  football\r\n\r\nUpdated: Oct 16, 2019 09:47 IS...
#
#                                                 Image Videos  \
# 0   https://www.hindustantimes.com/rf/image_size_9...     []
# 1   https://www.hindustantimes.com/rf/image_size_9...     []
# 2   https://www.hindustantimes.com/rf/image_size_9...     []
# 3   https://www.hindustantimes.com/rf/image_size_9...     []
# 4   https://www.hindustantimes.com/rf/image_size_9...     []
# 5   https://www.hindustantimes.com/rf/image_size_9...     []
# 6   https://www.hindustantimes.com/rf/image_size_9...     []
# 7   https://www.hindustantimes.com/rf/image_size_9...     []
# 8   https://www.hindustantimes.com/rf/image_size_9...     []
# 9   https://www.hindustantimes.com/rf/image_size_9...     []
# 10  https://www.hindustantimes.com/rf/image_size_9...     []
# 11  https://www.hindustantimes.com/rf/image_size_9...     []
# 12  https://www.hindustantimes.com/rf/image_size_9...     []
# 13  https://www.hindustantimes.com/rf/image_size_9...     []
# 14  https://www.hindustantimes.com/rf/image_size_9...     []
#
#                                                  Link       Published_Date
# 0   https://www.hindustantimes.com/football/kolkat...  2019-10-17T02:19:56
# 1   https://www.hindustantimes.com/football/manche...  2019-10-17T02:19:51
# 2   https://www.hindustantimes.com/football/arsena...  2019-10-17T12:03:32
# 3   https://www.hindustantimes.com/football/lionel...  2019-10-17T07:49:40
# 4   https://www.hindustantimes.com/football/liverp...  2019-10-17T06:56:36
# 5   https://www.hindustantimes.com/football/manche...  2019-10-17T06:56:34
# 6   https://www.hindustantimes.com/football/bulgar...  2019-10-16T04:13:16
# 7   https://www.hindustantimes.com/football/barcel...  2019-10-16T03:29:20
# 8   https://www.hindustantimes.com/football/real-m...  2019-10-16T12:40:18
# 9   https://www.hindustantimes.com/football/bangla...  2019-10-16T10:44:41
# 10  https://www.hindustantimes.com/football/lazio-...  2019-10-16T09:40:28
# 11  https://www.hindustantimes.com/football/india-...  2019-10-16T05:14:56
# 12  https://www.hindustantimes.com/football/igor-s...  2019-10-16T04:50:32
# 13  https://www.hindustantimes.com/football/spain-...  2019-10-16T04:35:49
# 14  https://www.hindustantimes.com/football/god-ma...  2019-10-16T04:17:44

# %%
df = df_articles.filter(["Title", "Text"])
df
# Out:
#                                                 Title  \
# 0   Kolkata in race to host India-Qatar World Cup ...
# 1   Manchester United will reinforce squad in Janu...
# 2   Arsenal’s Mesut Ozil recalls terrifying car-ja...
# 3           Lionel Messi wins sixth Golden Shoe award
# 4   Liverpool head to United with widest gulf in y...
# 5   Manchester City’s Sergio Aguero unhurt after c...
# 6   Bulgaria police hold six over racist abuse at ...
# 7   Barcelona’s Lionel Messi receives record sixth...
# 8   Real Madrid vs Barcelona: La Liga wants El Cla...
# 9   ‘Bangladesh draw unfortunate, team will learn ...
# 10  Lazio hit with stand closure for Celtic game o...
# 11  ‘India’s performance was no match to atmospher...
# 12  Igor Stimac rues his players’ inability to sco...
# 13  Spain make Euro 2020 with late Sweden draw, be...
# 14     God, man, superman: Finding Maradona in Naples
#
#                                                  Text
# 0   football\r\n\r\nUpdated: Oct 17, 2019 19:49 IS...
# 1   football\r\n\r\nUpdated: Oct 17, 2019 19:49 IS...
# 2   football\r\n\r\nUpdated: Oct 17, 2019 17:33 IS...
# 3   football\r\n\r\nUpdated: Oct 17, 2019 13:19 IS...
# 4   football\r\n\r\nUpdated: Oct 17, 2019 12:26 IS...
# 5   football\r\n\r\nUpdated: Oct 17, 2019 12:26 IS...
# 6   football\r\n\r\nUpdated: Oct 16, 2019 21:43 IS...
# 7   football\r\n\r\nUpdated: Oct 16, 2019 20:59 IS...
# 8   football\r\n\r\nUpdated: Oct 16, 2019 18:10 IS...
# 9   football\r\n\r\nUpdated: Oct 16, 2019 16:14 IS...
# 10  football\r\n\r\nUpdated: Oct 16, 2019 15:10 IS...
# 11  football\r\n\r\nUpdated: Oct 16, 2019 10:44 IS...
# 12  football\r\n\r\nUpdated: Oct 16, 2019 10:20 IS...
# 13  football\r\n\r\nUpdated: Oct 16, 2019 10:05 IS...
# 14  football\r\n\r\nUpdated: Oct 16, 2019 09:47 IS...

# %%
for i in range(0,df.last_valid_index()+1):
    x = df.iloc[i]['Text']
    a = df.iloc[i]['Text'][43:(len(x)-41)]
    df.iloc[i]['Text'] = a

# %%
df
# Out:
#                                                 Title  \
# 0   Kolkata in race to host India-Qatar World Cup ...
# 1   Manchester United will reinforce squad in Janu...
# 2   Arsenal’s Mesut Ozil recalls terrifying car-ja...
# 3           Lionel Messi wins sixth Golden Shoe award
# 4   Liverpool head to United with widest gulf in y...
# 5   Manchester City’s Sergio Aguero unhurt after c...
# 6   Bulgaria police hold six over racist abuse at ...
# 7   Barcelona’s Lionel Messi receives record sixth...
# 8   Real Madrid vs Barcelona: La Liga wants El Cla...
# 9   ‘Bangladesh draw unfortunate, team will learn ...
# 10  Lazio hit with stand closure for Celtic game o...
# 11  ‘India’s performance was no match to atmospher...
# 12  Igor Stimac rues his players’ inability to sco...
# 13  Spain make Euro 2020 with late Sweden draw, be...
# 14     God, man, superman: Finding Maradona in Naples
#
#                                                  Text
# 0   \r\n\r\nThe iconic Salt Lake Stadium could onc...
# 1   \r\n\r\nManchester United will try to sign one...
# 2   \r\n\r\nMezut Ozil has opened up about being a...
# 3   \r\n\r\nLionel Messi, star striker of FC Barce...
# 4   \r\n\r\nPremier League leaders Liverpool head ...
# 5   \r\n\r\nManchester City striker Sergio Aguero ...
# 6   \r\n\r\nSix Bulgarians have been detained over...
# 7   \r\n\r\nBarcelona forward Lionel Messi picked ...
# 8   \r\n\r\nThe Spanish football league said Wedne...
# 9   \r\n\r\nFormer India captain Bhaichung Bhutia ...
# 10  \r\n\r\nItalian club Lazio have been hit with ...
# 11  \r\n\r\nIndia captain Sunil Chhetri on Wednesd...
# 12  \r\n\r\nIndian football head coach Igor Stimac...
# 13  \r\n\r\nRodrigo Moreno fired Spain into Euro 2...
# 14  \r\n\r\nOne consequence of revisiting the life...

# %%
from pycorenlp import StanfordCoreNLP
import json, string
nlp=StanfordCoreNLP('http://localhost:9000')

# %%
text_input = 'this is a test.'
print('text_input: {0}'.format(text_input))
text_output = nlp.annotate(text_input, properties={
                    'annotators': 'tokenize,ssplit',
                    'outputFormat': 'json'
                })
print('text_output: {0}'.format(text_output))
# Out:
# text_input: this is a test.
# text_output: {'sentences': [{'index': 0, 'tokens': [{'index': 1, 'word': 'this', 'originalText': 'this', 'characterOffsetBegin': 0, 'characterOffsetEnd': 4, 'before': '', 'after': ' '}, {'index': 2, 'word': 'is', 'originalText': 'is', 'characterOffsetBegin': 5, 'characterOffsetEnd': 7, 'before': ' ', 'after': ' '}, {'index': 3, 'word': 'a', 'originalText': 'a', 'characterOffsetBegin': 8, 'characterOffsetEnd': 9, 'before': ' ', 'after': ' '}, {'index': 4, 'word': 'test', 'originalText': 'test', 'characterOffsetBegin': 10, 'characterOffsetEnd': 14, 'before': ' ', 'after': ''}, {'index': 5, 'word': '.', 'originalText': '.', 'characterOffsetBegin': 14, 'characterOffsetEnd': 15, 'before': '', 'after': ''}]}]}

# %%
def lemmatize_corenlp(conn_nlp, sentence):
    props = {
        'annotators': 'pos,lemma,tokenize,ssplit',
        'pipelineLanguage': 'en',
        'outputFormat': 'json'
    }

    # tokenize into words
    #sents = conn_nlp.word_tokenize(sentence)

    # remove punctuations from tokenised list
    sents_no_punct = [s for s in sentence if s not in string.punctuation]

    # form sentence
    sentence2 = " ".join(sents_no_punct)

    # annotate to get lemma
    parsed_str = conn_nlp.annotate(sentence2, properties=props)
    parsed_dict = json.loads(parsed_str)    # contains the text which is annotated
    
    # extract the lemma for each word
    lemma_list = [v 
                  for d in parsed_dict['sentences'][0]['tokens'] 
                      for k,v in d.items() 
                          if k == 'lemma'
                 ]

    # form sentence and return it
    return " ".join(lemma_list)

# %%
# make the connection and call `lemmatize_corenlp`
#nlp = StanfordCoreNLP('http://localhost', port=9000, timeout=30000)

# %%
# output for lemmatizing only
for i in range(0, df.last_valid_index()+1):
    df.iloc[i]['Title'] = lemmatize_corenlp(conn_nlp=nlp, sentence=df.iloc[i]['Title'])
    df.iloc[i]['Text'] = lemmatize_corenlp(conn_nlp=nlp, sentence=df.iloc[i]['Text'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-94ab80cb8ebc> in <module>
#       1 # output for lemmatizing only
#       2 for i in range(0, df.last_valid_index()+1):
# ----> 3     df.iloc[i]['Title'] = lemmatize_corenlp(conn_nlp=nlp, sentence=df.iloc[i]['Title'])
#       4     df.iloc[i]['Text'] = lemmatize_corenlp(conn_nlp=nlp, sentence=df.iloc[i]['Text'])
#
# <ipython-input-37-1bc878c39ac5> in lemmatize_corenlp(conn_nlp, sentence)
#      17     # annotate to get lemma
#      18     parsed_str = conn_nlp.annotate(sentence2, properties=props)
# ---> 19     parsed_dict = json.loads(parsed_str)    # contains the text which is annotated
#      20
#      21     # extract the lemma for each word
#
# ~\Anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     339     else:
#     340         if not isinstance(s, (bytes, bytearray)):
# --> 341             raise TypeError(f'the JSON object must be str, bytes or bytearray, '
#     342                             f'not {s.__class__.__name__}')
#     343         s = s.decode(detect_encoding(s), 'surrogatepass')
#
# TypeError: the JSON object must be str, bytes or bytearray, not dict
